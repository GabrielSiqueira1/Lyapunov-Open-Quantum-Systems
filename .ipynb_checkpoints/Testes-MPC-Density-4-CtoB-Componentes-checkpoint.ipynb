# %%
# Bilbiotecas para auxílio na programação matemática
import math, sys 
import numpy as np
import sympy as sp
import cmath
import time

from scipy import sparse # Produção das diagonais das matrizes
from scipy.sparse import diags 
from scipy.linalg import expm

# Plotagem 2D e 3D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm


from os import path # Suficiente para manipulação de arquivos
    
# Para solução exata
from scipy.special import hermite
from math import factorial

# %matplotlib inline
count = 0

# Para otimização dos sistemas
from scipy import optimize
from random import randint, uniform, random

# %%
# Manipulação das matrizes, soma e subtração

def somar(A, B):
    C = []
    num_linhas_a = len(A)
    num_colunas_a = len(A[0])
    
    for i in range (num_linhas_a):
        linha = [0]*num_colunas_a
        C.append(linha)
        for j in range(num_colunas_a):
            C[i][j] = A[i][j] + B[i][j]

    return C

def sub(A, B):
    C = []
    num_linhas_a = len(A)
    num_colunas_a = len(A[0])
    
    for i in range (num_linhas_a):
        linha = [0]*num_colunas_a
        C.append(linha)
        for j in range(num_linhas_a):
            C[i][j] = A[i][j] - B[i][j]

    return C

# %%
## CONSTANTES PARA O CONTROLADOR

# Considerações: constante de Planck verdadeira: 1, massa: 1

TEMPO_ANALISE = 10 
QUANTIDADE_PONTOS_AMOSTRAGEM = 1000
PASSO = TEMPO_ANALISE/QUANTIDADE_PONTOS_AMOSTRAGEM

MIN_HORIZONTE = 3 # Horizonte mínimo da análise
MAX_HORIZONTE = 30 # Horizonte máximo da análise

# Com horizonte em 10, a avaliação dura em torno de 80 minutos 

DESEJADO = [[0.75],[0.66]] # [[c1];[c2]] = [[0.707],[-0.707]]
RHO_DESEJADO = np.matmul(DESEJADO, np.transpose(DESEJADO))

# Determinação dos valores de início e fim da análise
num = PASSO
contador = 0
while num < 1:
    num *= 10
    contador += 1

EXPOENTE = contador
INICIO_ANALISE = 0*10**(-EXPOENTE) # Tempo inicial da analise em um horizonte
FINAL_ANALISE = (1*10**(-EXPOENTE))+PASSO # Tempo final da analise em um horizonte

# %%
## CONSTANTES PARA O ALGORITMO GENÉTICO

ELITISMO = True
PORCENTAGEM_ELITISMO = 0.20

TAMANHO_POP = 50
TAXA_MUTACAO = 0.10
TAXA_CRUZAMENTO = 0.70
GERACOES = 100

# Valores mínimos e máximos para gerar uma população
MIN = -5
MAX = 5

# %%
def dpsi_dt(t, ro, H): # A derivada da ro em relação ao tempo não tem dependência temporal
    A = np.zeros((2,2), dtype=np.complex_)
    A = (np.dot(H,ro))-(np.dot(ro, H)) # [H,p]
    return -1j*A

# Runge-Kutta de quarta ordem

def runge_kutta(onda, fator_runge_kutta, hamiltoniano, tempo_inicial = 0):

    k1 = dpsi_dt(tempo_inicial, onda, hamiltoniano)
    k2 = dpsi_dt(tempo_inicial + 0.5 * fator_runge_kutta, somar(onda, np.dot((0.5*fator_runge_kutta), k1)), hamiltoniano)
    k3 = dpsi_dt(tempo_inicial + 0.5 * fator_runge_kutta, somar(onda, np.dot((0.5*fator_runge_kutta), k2)), hamiltoniano)
    k4 = dpsi_dt(tempo_inicial + fator_runge_kutta, somar(onda, np.dot(fator_runge_kutta, k3)), hamiltoniano)
    
    ## y(i+1) = y(i) + h/6*(k1+2*k2+2*k3+k4)
    
    A = somar(np.dot(2,k3), k4)
    B = somar(np.dot(2,k2), k1)
    C = somar(A, B)

    runge = somar(onda,np.dot((fator_runge_kutta / 6.0),(C)))
    
    return runge

# %%
def func_objetivo(vetor_controles, tempo_atual, rho_desejado, 
                  rho_atual, H, horizonte, fator_runge_kutta):
    
    fo = 0
    pos = 0
    
    tempo_inicial = INICIO_ANALISE
    tempo_final = FINAL_ANALISE
    
    controles = np.zeros((2,2), dtype=np.complex_)
    controles = [[0, complex(vetor_controles[0], vetor_controles[1])], 
                 [complex(vetor_controles[0], -vetor_controles[1]), 0]]
    
    matriz_inicial = rho_atual

    matriz_desejada = np.zeros((2,2),dtype=np.complex_)
    hamiltoniano = H

    H = [[np.exp(-1j*np.pi*tempo_atual/2),0],[0,np.exp(1j*np.pi*tempo_atual/2)]]
    U = H
    U = np.asmatrix(U)
    U_dagger = U.getH()
    teste = np.dot(np.dot(U,rho_desejado),U_dagger)
    matriz_desejada = np.squeeze(np.asarray(teste))

    matriz_teste = sub(matriz_inicial, matriz_desejada)
    
    teste = []
    for m in range(0, 2):
        teste.append(abs(matriz_teste[0][m])+abs(matriz_teste[0][m]))
    
    fo += max(teste)

    runge = runge_kutta(matriz_inicial, fator_runge_kutta, 
                        somar(hamiltoniano, controles), tempo_inicial = tempo_inicial)

    matriz_inicial = runge

    tempo_inicial = round(tempo_inicial+PASSO, EXPOENTE)
    tempo_final = round(tempo_final+PASSO, EXPOENTE)
    tempo = round(tempo_atual+PASSO, EXPOENTE)
    pos += 2

    while horizonte > 1:
        
        H = [[np.exp(-1j*np.pi*tempo/2),0],[0,np.exp(1j*np.pi*tempo/2)]]
        U = H
        U = np.asmatrix(U)
        U_dagger = U.getH()
        teste = np.dot(np.dot(U,rho_desejado),U_dagger)
        matriz_desejada = np.squeeze(np.asarray(teste))
        
        teste = []
        for m in range(0, 2):
            teste.append(abs(matriz_teste[0][m])+abs(matriz_teste[0][m]))

        matriz_teste = sub(matriz_inicial, matriz_desejada)
        
        fo += max(teste)
        
        controles = [[0, complex(vetor_controles[pos], vetor_controles[pos+1])], 
                     [complex(vetor_controles[pos], -vetor_controles[pos+1]), 0]]

        runge = runge_kutta(matriz_inicial, fator_runge_kutta, 
                        somar(hamiltoniano, controles), tempo_inicial = tempo_inicial)

        matriz_inicial = runge

        tempo_inicial = round(tempo_inicial+PASSO, EXPOENTE)
        tempo_final = round(tempo_final+PASSO, EXPOENTE)
        tempo = round(tempo_atual+PASSO, EXPOENTE)
        horizonte -= 1

    return fo

# %%
def main(horizonte, rho_inicial):
    
    u = [] # Controles 
    for i in range(0, 2*horizonte):
        u.append(uniform(-5,5))

    evolucao_1 = np.zeros((2,QUANTIDADE_PONTOS_AMOSTRAGEM), dtype=np.complex_)
    evolucao_2 = np.zeros((2,QUANTIDADE_PONTOS_AMOSTRAGEM), dtype=np.complex_)
        
    # O que será retornado por essa função
    
    vetor_controles = np.zeros((1, QUANTIDADE_PONTOS_AMOSTRAGEM), dtype=np.complex_) # Valores de controle
    constantes = np.zeros((2, QUANTIDADE_PONTOS_AMOSTRAGEM), dtype=np.complex_) # Para verificar se as integrais estão resultando em 1
    valores_onda = np.zeros((2, QUANTIDADE_PONTOS_AMOSTRAGEM), dtype=np.complex_)
    
    H = np.zeros((2,2), dtype=np.complex_)
    H = [[(3/2*np.pi), 0], [0, (1/2*np.pi)]]
    
    tempo = 0
    pos = 0
    while tempo < TEMPO_ANALISE:

        evolucao_1[0][pos] = rho_inicial[0][0]
        evolucao_1[1][pos] = rho_inicial[1][1]

        evolucao_2[0][pos] = rho_inicial[0][1]
        evolucao_2[1][pos] = rho_inicial[1][0]
    
        resultado = optimize.minimize(func_objetivo, u, args=(tempo, RHO_DESEJADO, rho_inicial, H, horizonte, PASSO), method='SLSQP')

        print('------------------')
        print(resultado)
        
        controle = np.zeros((2,2), dtype=np.complex_)
        controle = [[0, complex(resultado.x[0], resultado.x[1])],[complex(resultado.x[0], -resultado.x[1]), 0]]
        H = somar(H, controle)
    
        ## Adaptação da onda ao controle
        
        rho_avancado = runge_kutta(rho_inicial, PASSO, H, tempo_inicial = INICIO_ANALISE)
        rho_inicial = rho_avancado
        
        # Reset
        H = [[(3/2*np.pi), 0], [0, (1/2*np.pi)]]
    
        u = [] # Controles 
        for i in range(0, 2*horizonte):
            u.append(resultado.x[0])
            u.append(resultado.x[1])
        
        pos += 1
        tempo = round(tempo+PASSO, EXPOENTE)

    return evolucao_1, evolucao_2

# %%
# Plotagem 2D e 3D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm

def plot_componentes(valores_onda,  evolucao_d, componente):
    
    ts1 = np.linspace(0, TEMPO_ANALISE, QUANTIDADE_PONTOS_AMOSTRAGEM)
    ts2 = np.linspace(0, TEMPO_ANALISE, QUANTIDADE_PONTOS_AMOSTRAGEM)
    
    real_primeiro = [elemento.real for elemento in valores_onda[componente-1]]
    imaginario_primeiro = [elemento.imag for elemento in valores_onda[componente-1]]
    
    real_segundo = [elemento.real for elemento in evolucao_d[componente-1]]
    imaginario_segundo = [elemento.imag for elemento in evolucao_d[componente-1]]
    
    # Plotagem
    plt.subplot(2,1,1)

    plt.ylabel('Pesos') 
    plt.xlabel('Tempo') 
    plt.title(f"{componente}ª componente -> real")
    plt.plot(ts1, real_primeiro, color='r', marker='*', linewidth=1, markersize=1, label="primeiro")
    plt.plot(ts2, real_segundo, color='b', marker='o',  linewidth=1, markersize=1, label="segundo")
    plt.legend(loc='upper right')
    
    plt.subplot(2,1,2)

    plt.ylabel('Imaginário') 
    plt.xlabel('Tempo') 
    plt.title(f"{componente}ª componente -> imaginária")
    plt.plot(ts1, imaginario_primeiro, color='r', marker='*', linewidth=1, markersize=1, label="primeiro")
    plt.plot(ts2, imaginario_segundo, color='b', marker='o',  linewidth=1, markersize=1, label="segundo")
    plt.legend(loc='upper right')

    plt.axis([0,TEMPO_ANALISE,0,1])

    plt.tight_layout()

# %%
PSI = np.ones((2,1), dtype=np.complex_)
PSI = [[0.80],[0.60]]
ro = np.matmul(PSI, np.transpose(PSI))
evolucao_1, evolucao_2 = main(4, ro)
# Out:
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.34648299877382693
#        x: [ 4.494e+00 -8.675e+00 -1.894e+00  1.700e+00  2.731e+00
#             2.669e+00  2.946e+00 -2.379e+00]
#      nit: 29
#      jac: [-9.332e-05  2.979e-04 -2.526e-03  4.952e-04  0.000e+00
#             0.000e+00  0.000e+00  0.000e+00]
#     nfev: 291
#     njev: 29
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0649948791642822
#        x: [ 3.012e+00 -2.564e-01 ...  4.494e+00 -8.675e+00]
#      nit: 35
#      jac: [ 3.983e-03  5.900e-04 ...  0.000e+00  0.000e+00]
#     nfev: 646
#     njev: 35
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.08788344978594893
#        x: [ 2.867e+00  7.019e-02 ...  3.012e+00 -2.564e-01]
#      nit: 15
#      jac: [ 4.161e-03  6.310e-04 ...  0.000e+00  0.000e+00]
#     nfev: 275
#     njev: 15
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.06622199918888656
#        x: [-1.268e+01  1.984e+00 ...  2.867e+00  7.019e-02]
#      nit: 56
#      jac: [-7.916e-04 -5.093e-03 ...  0.000e+00  0.000e+00]
#     nfev: 994
#     njev: 56
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.11232577478584976
#        x: [-1.217e+01  3.988e-01 ... -1.268e+01  1.984e+00]
#      nit: 7
#      jac: [-4.342e-03 -1.219e-02 ...  0.000e+00  0.000e+00]
#     nfev: 140
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.19770825247968535
#        x: [-1.191e+01  1.480e+00 ... -1.217e+01  3.988e-01]
#      nit: 8
#      jac: [-1.431e-03  9.417e-03 ...  0.000e+00  0.000e+00]
#     nfev: 157
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.26929183241955235
#        x: [-1.168e+01  2.277e+00 ... -1.191e+01  1.480e+00]
#      nit: 9
#      jac: [-2.590e-04  9.330e-03 ...  0.000e+00  0.000e+00]
#     nfev: 177
#     njev: 9
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.32370090120676664
#        x: [-1.118e+01  2.910e+00 ... -1.168e+01  2.277e+00]
#      nit: 21
#      jac: [ 6.593e-04  9.071e-03 ...  0.000e+00  0.000e+00]
#     nfev: 405
#     njev: 21
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.36762838717511204
#        x: [-1.098e+01  3.455e+00 ... -1.118e+01  2.910e+00]
#      nit: 8
#      jac: [ 1.428e-03  8.828e-03 ...  0.000e+00  0.000e+00]
#     nfev: 161
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.327279492461396
#        x: [ 4.562e+01 -1.297e+01 ... -1.098e+01  3.455e+00]
#      nit: 33
#      jac: [-9.503e-03 -2.379e-02 ...  0.000e+00  0.000e+00]
#     nfev: 598
#     njev: 33
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.07518522830486443
#        x: [ 5.574e+00 -1.082e+00 ...  4.562e+01 -1.297e+01]
#      nit: 48
#      jac: [-5.144e-03 -1.723e-02 ...  0.000e+00  0.000e+00]
#     nfev: 857
#     njev: 48
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.00838103793759942
#        x: [-3.275e-01  1.452e-01 ...  5.574e+00 -1.082e+00]
#      nit: 45
#      jac: [ 5.457e-03  1.553e-02 ...  0.000e+00  0.000e+00]
#     nfev: 793
#     njev: 45
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.02640633919169224
#        x: [ 7.598e+00 -3.625e+00 ... -3.275e-01  1.452e-01]
#      nit: 21
#      jac: [-4.189e-03 -1.796e-02 ...  0.000e+00  0.000e+00]
#     nfev: 378
#     njev: 21
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.1007873472242447
#        x: [ 7.509e+00 -3.678e+00 ...  7.598e+00 -3.625e+00]
#      nit: 8
#      jac: [ 6.250e-03  3.730e-03 ...  0.000e+00  0.000e+00]
#     nfev: 163
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.10472530755338799
#        x: [-5.652e+00  2.068e+00 ...  7.509e+00 -3.678e+00]
#      nit: 64
#      jac: [-1.014e-02 -1.922e-02 ...  0.000e+00  0.000e+00]
#     nfev: 1154
#     njev: 64
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09821602872327223
#        x: [-5.017e+00  3.287e+00 ... -5.652e+00  2.068e+00]
#      nit: 11
#      jac: [ 6.018e-04  1.287e-03 ...  0.000e+00  0.000e+00]
#     nfev: 203
#     njev: 11
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.07621677546481537
#        x: [-4.885e+00  3.360e+00 ... -5.017e+00  3.287e+00]
#      nit: 12
#      jac: [-2.062e-03  3.023e-03 ...  0.000e+00  0.000e+00]
#     nfev: 224
#     njev: 12
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.041355933221548465
#        x: [ 2.346e+00 -8.965e-01 ... -4.885e+00  3.360e+00]
#      nit: 22
#      jac: [ 7.981e-03  1.797e-02 ...  0.000e+00  0.000e+00]
#     nfev: 442
#     njev: 22
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.037282814756703364
#        x: [ 2.070e+00 -1.331e+00 ...  2.346e+00 -8.965e-01]
#      nit: 21
#      jac: [-7.717e-04 -1.184e-03 ...  0.000e+00  0.000e+00]
#     nfev: 395
#     njev: 21
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.048222064652465355
#        x: [ 2.011e+00 -1.397e+00 ...  2.070e+00 -1.331e+00]
#      nit: 8
#      jac: [-9.072e-04 -1.422e-03 ...  0.000e+00  0.000e+00]
#     nfev: 149
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.06252422469404842
#        x: [ 1.885e+00 -1.517e+00 ...  2.011e+00 -1.397e+00]
#      nit: 9
#      jac: [ 1.364e-02  1.490e-02 ...  0.000e+00  0.000e+00]
#     nfev: 169
#     njev: 9
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.07664398822078192
#        x: [-2.486e-01 -1.703e-01 ...  1.885e+00 -1.517e+00]
#      nit: 26
#      jac: [-9.858e-04 -1.708e-03 ...  0.000e+00  0.000e+00]
#     nfev: 460
#     njev: 26
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.06893876000976705
#        x: [-2.473e+00  3.092e+00 ... -2.486e-01 -1.703e-01]
#      nit: 33
#      jac: [ 4.775e-03 -2.320e-03 ...  0.000e+00  0.000e+00]
#     nfev: 601
#     njev: 33
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.06885125542494228
#        x: [-3.396e+00  1.745e+00 ... -2.473e+00  3.092e+00]
#      nit: 20
#      jac: [-2.105e-04  3.547e-04 ...  0.000e+00  0.000e+00]
#     nfev: 373
#     njev: 20
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.014069337872982944
#        x: [-9.975e-01  1.454e+00 ... -3.396e+00  1.745e+00]
#      nit: 95
#      jac: [-2.878e-03 -3.581e-03 ...  0.000e+00  0.000e+00]
#     nfev: 1695
#     njev: 95
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.027666251542790073
#        x: [ 4.396e+00 -3.812e+00 ... -9.975e-01  1.454e+00]
#      nit: 29
#      jac: [-1.068e-03 -1.098e-03 ...  0.000e+00  0.000e+00]
#     nfev: 529
#     njev: 29
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.07325774099504108
#        x: [ 3.375e+00 -4.540e+00 ...  4.396e+00 -3.812e+00]
#      nit: 15
#      jac: [ 6.010e-03 -1.184e-03 ...  0.000e+00  0.000e+00]
#     nfev: 290
#     njev: 15
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0860048024429251
#        x: [-3.610e+00  5.248e+00 ...  3.375e+00 -4.540e+00]
#      nit: 44
#      jac: [-8.442e-04 -7.662e-04 ...  0.000e+00  0.000e+00]
#     nfev: 810
#     njev: 44
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.07960568360979364
#        x: [-4.567e+00  4.271e+00 ... -3.610e+00  5.248e+00]
#      nit: 14
#      jac: [-6.385e-04  5.275e-03 ...  0.000e+00  0.000e+00]
#     nfev: 269
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.08471806847982324
#        x: [-4.146e+00  4.496e+00 ... -4.567e+00  4.271e+00]
#      nit: 10
#      jac: [ 5.793e-04  5.987e-03 ...  0.000e+00  0.000e+00]
#     nfev: 196
#     njev: 10
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.1346899358693579
#        x: [-3.840e+00  4.639e+00 ... -4.146e+00  4.496e+00]
#      nit: 15
#      jac: [ 1.218e-03  5.632e-03 ...  0.000e+00  0.000e+00]
#     nfev: 321
#     njev: 15
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.1792313684263986
#        x: [-3.532e+00  4.773e+00 ... -3.840e+00  4.639e+00]
#      nit: 14
#      jac: [ 1.724e-03  5.218e-03 ...  0.000e+00  0.000e+00]
#     nfev: 294
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.21836618479447023
#        x: [-3.242e+00  4.890e+00 ... -3.532e+00  4.773e+00]
#      nit: 15
#      jac: [ 2.145e-03  4.808e-03 ...  0.000e+00  0.000e+00]
#     nfev: 321
#     njev: 15
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.25280480712225234
#        x: [-2.967e+00  4.991e+00 ... -3.242e+00  4.890e+00]
#      nit: 15
#      jac: [ 2.501e-03  4.413e-03 ...  0.000e+00  0.000e+00]
#     nfev: 321
#     njev: 15
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.2831747370009604
#        x: [-2.704e+00  5.079e+00 ... -2.967e+00  4.991e+00]
#      nit: 15
#      jac: [ 2.804e-03  4.036e-03 ...  0.000e+00  0.000e+00]
#     nfev: 321
#     njev: 15
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.3100177364028569
#        x: [-2.452e+00  5.155e+00 ... -2.704e+00  5.079e+00]
#      nit: 15
#      jac: [ 3.062e-03  3.676e-03 ...  0.000e+00  0.000e+00]
#     nfev: 321
#     njev: 15
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.3337895002315221
#        x: [-2.209e+00  5.221e+00 ... -2.452e+00  5.155e+00]
#      nit: 15
#      jac: [ 3.283e-03  3.335e-03 ...  0.000e+00  0.000e+00]
#     nfev: 321
#     njev: 15
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.35487701145162176
#        x: [-1.974e+00  5.277e+00 ... -2.209e+00  5.221e+00]
#      nit: 15
#      jac: [ 3.471e-03  3.010e-03 ...  0.000e+00  0.000e+00]
#     nfev: 321
#     njev: 15
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.37361105916070986
#        x: [-1.746e+00  5.325e+00 ... -1.974e+00  5.277e+00]
#      nit: 15
#      jac: [ 3.631e-03  2.701e-03 ...  0.000e+00  0.000e+00]
#     nfev: 321
#     njev: 15
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.3902759225996968
#        x: [-1.525e+00  5.364e+00 ... -1.746e+00  5.325e+00]
#      nit: 15
#      jac: [ 3.767e-03  2.406e-03 ...  0.000e+00  0.000e+00]
#     nfev: 321
#     njev: 15
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.405117091229159
#        x: [-1.308e+00  5.396e+00 ... -1.525e+00  5.364e+00]
#      nit: 15
#      jac: [ 3.881e-03  2.126e-03 ...  0.000e+00  0.000e+00]
#     nfev: 321
#     njev: 15
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.41834912390151846
#        x: [-1.097e+00  5.423e+00 ... -1.308e+00  5.396e+00]
#      nit: 14
#      jac: [ 3.976e-03  1.858e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.43015524720190224
#        x: [-8.903e-01  5.442e+00 ... -1.097e+00  5.423e+00]
#      nit: 14
#      jac: [ 4.056e-03  1.602e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.44070383070742847
#        x: [-6.873e-01  5.455e+00 ... -8.903e-01  5.442e+00]
#      nit: 14
#      jac: [ 4.120e-03  1.357e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.4501314841884627
#        x: [-4.878e-01  5.462e+00 ... -6.873e-01  5.455e+00]
#      nit: 14
#      jac: [ 4.171e-03  1.122e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.4585620558753331
#        x: [-2.916e-01  5.462e+00 ... -4.878e-01  5.462e+00]
#      nit: 14
#      jac: [ 4.210e-03  8.967e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.4661050292047445
#        x: [-9.852e-02  5.457e+00 ... -2.916e-01  5.462e+00]
#      nit: 14
#      jac: [ 4.238e-03  6.797e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.47285709455444125
#        x: [ 9.165e-02  5.446e+00 ... -9.852e-02  5.457e+00]
#      nit: 14
#      jac: [ 4.256e-03  4.707e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.47890379544016526
#        x: [ 2.790e-01  5.430e+00 ...  9.165e-02  5.446e+00]
#      nit: 14
#      jac: [ 4.265e-03  2.693e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.48432093281986777
#        x: [ 4.637e-01  5.408e+00 ...  2.790e-01  5.430e+00]
#      nit: 14
#      jac: [ 4.266e-03  7.491e-05 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.48917576934558366
#        x: [ 6.457e-01  5.380e+00 ...  4.637e-01  5.408e+00]
#      nit: 14
#      jac: [ 4.259e-03 -1.130e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.4935280661891758
#        x: [ 8.251e-01  5.348e+00 ...  6.457e-01  5.380e+00]
#      nit: 14
#      jac: [ 4.246e-03 -2.947e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.4974309796442427
#        x: [ 1.002e+00  5.310e+00 ...  8.251e-01  5.348e+00]
#      nit: 14
#      jac: [ 4.226e-03 -4.706e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.500931838665606
#        x: [ 1.176e+00  5.267e+00 ...  1.002e+00  5.310e+00]
#      nit: 14
#      jac: [ 4.199e-03 -6.411e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5040728222128847
#        x: [ 1.348e+00  5.219e+00 ...  1.176e+00  5.267e+00]
#      nit: 14
#      jac: [ 4.168e-03 -8.065e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5068915499380107
#        x: [ 1.517e+00  5.166e+00 ...  1.348e+00  5.219e+00]
#      nit: 14
#      jac: [ 4.130e-03 -9.669e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5094215999698998
#        x: [ 1.683e+00  5.109e+00 ...  1.517e+00  5.166e+00]
#      nit: 14
#      jac: [ 4.088e-03 -1.123e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5116929628900158
#        x: [ 1.847e+00  5.046e+00 ...  1.683e+00  5.109e+00]
#      nit: 14
#      jac: [ 4.041e-03 -1.274e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5137324411240299
#        x: [ 2.008e+00  4.979e+00 ...  1.847e+00  5.046e+00]
#      nit: 14
#      jac: [ 3.989e-03 -1.421e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5155640009552898
#        x: [ 2.166e+00  4.907e+00 ...  2.008e+00  4.979e+00]
#      nit: 14
#      jac: [ 3.933e-03 -1.564e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5172090830226433
#        x: [ 2.321e+00  4.831e+00 ...  2.166e+00  4.907e+00]
#      nit: 14
#      jac: [ 3.873e-03 -1.702e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5186868770462036
#        x: [ 2.474e+00  4.750e+00 ...  2.321e+00  4.831e+00]
#      nit: 14
#      jac: [ 3.808e-03 -1.837e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5200145651419199
#        x: [ 2.623e+00  4.664e+00 ...  2.474e+00  4.750e+00]
#      nit: 14
#      jac: [ 3.740e-03 -1.968e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5212075373585681
#        x: [ 2.769e+00  4.575e+00 ...  2.623e+00  4.664e+00]
#      nit: 14
#      jac: [ 3.668e-03 -2.095e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.522279583497172
#        x: [ 2.911e+00  4.481e+00 ...  2.769e+00  4.575e+00]
#      nit: 14
#      jac: [ 3.593e-03 -2.219e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5232430629897907
#        x: [ 3.051e+00  4.382e+00 ...  2.911e+00  4.481e+00]
#      nit: 14
#      jac: [ 3.514e-03 -2.338e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5241090566537714
#        x: [ 3.187e+00  4.280e+00 ...  3.051e+00  4.382e+00]
#      nit: 14
#      jac: [ 3.432e-03 -2.454e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5248875012741618
#        x: [ 3.319e+00  4.174e+00 ...  3.187e+00  4.280e+00]
#      nit: 14
#      jac: [ 3.346e-03 -2.567e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.525587309743733
#        x: [ 3.448e+00  4.064e+00 ...  3.319e+00  4.174e+00]
#      nit: 14
#      jac: [ 3.257e-03 -2.675e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5262164789256257
#        x: [ 3.573e+00  3.950e+00 ...  3.448e+00  4.064e+00]
#      nit: 14
#      jac: [ 3.166e-03 -2.780e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5267821842174936
#        x: [ 3.694e+00  3.832e+00 ...  3.573e+00  3.950e+00]
#      nit: 14
#      jac: [ 3.071e-03 -2.882e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5272908660777649
#        x: [ 3.811e+00  3.711e+00 ...  3.694e+00  3.832e+00]
#      nit: 14
#      jac: [ 2.974e-03 -2.979e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5277483058948139
#        x: [ 3.925e+00  3.587e+00 ...  3.811e+00  3.711e+00]
#      nit: 14
#      jac: [ 2.874e-03 -3.074e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5281596942157614
#        x: [ 4.034e+00  3.459e+00 ...  3.925e+00  3.587e+00]
#      nit: 14
#      jac: [ 2.771e-03 -3.164e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5285296918098278
#        x: [ 4.139e+00  3.328e+00 ...  4.034e+00  3.459e+00]
#      nit: 14
#      jac: [ 2.666e-03 -3.251e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5288624844472449
#        x: [ 4.240e+00  3.194e+00 ...  4.139e+00  3.328e+00]
#      nit: 14
#      jac: [ 2.559e-03 -3.333e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5291618314719042
#        x: [ 4.336e+00  3.057e+00 ...  4.240e+00  3.194e+00]
#      nit: 14
#      jac: [ 2.449e-03 -3.413e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5294311100467811
#        x: [ 4.428e+00  2.917e+00 ...  4.336e+00  3.057e+00]
#      nit: 14
#      jac: [ 2.337e-03 -3.488e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5296733538524934
#        x: [ 4.516e+00  2.774e+00 ...  4.428e+00  2.917e+00]
#      nit: 14
#      jac: [ 2.223e-03 -3.559e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5298912890114571
#        x: [ 4.598e+00  2.629e+00 ...  4.516e+00  2.774e+00]
#      nit: 14
#      jac: [ 2.107e-03 -3.627e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5300873648557937
#        x: [ 4.677e+00  2.482e+00 ...  4.598e+00  2.629e+00]
#      nit: 14
#      jac: [ 1.989e-03 -3.691e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.530263782734401
#        x: [ 4.750e+00  2.332e+00 ...  4.677e+00  2.482e+00]
#      nit: 14
#      jac: [ 1.870e-03 -3.751e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5304225206984121
#        x: [ 4.819e+00  2.180e+00 ...  4.750e+00  2.332e+00]
#      nit: 14
#      jac: [ 1.749e-03 -3.807e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5305653572680287
#        x: [ 4.882e+00  2.027e+00 ...  4.819e+00  2.180e+00]
#      nit: 14
#      jac: [ 1.626e-03 -3.859e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5306938907242715
#        x: [ 4.941e+00  1.871e+00 ...  4.882e+00  2.027e+00]
#      nit: 14
#      jac: [ 1.502e-03 -3.906e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.530809557867821
#        x: [ 4.995e+00  1.714e+00 ...  4.941e+00  1.871e+00]
#      nit: 14
#      jac: [ 1.377e-03 -3.950e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5309136507080924
#        x: [ 5.044e+00  1.555e+00 ...  4.995e+00  1.714e+00]
#      nit: 14
#      jac: [ 1.250e-03 -3.990e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.53100733058722
#        x: [ 5.088e+00  1.395e+00 ...  5.044e+00  1.555e+00]
#      nit: 14
#      jac: [ 1.123e-03 -4.026e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5310916419916337
#        x: [ 5.127e+00  1.233e+00 ...  5.088e+00  1.395e+00]
#      nit: 14
#      jac: [ 9.943e-04 -4.058e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5311675240326317
#        x: [ 5.161e+00  1.071e+00 ...  5.127e+00  1.233e+00]
#      nit: 14
#      jac: [ 8.652e-04 -4.085e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5312358212025052
#        x: [ 5.190e+00  9.078e-01 ...  5.161e+00  1.071e+00]
#      nit: 14
#      jac: [ 7.353e-04 -4.108e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5312972932068847
#        x: [ 5.213e+00  7.438e-01 ...  5.190e+00  9.078e-01]
#      nit: 14
#      jac: [ 6.050e-04 -4.128e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5313526230690175
#        x: [ 5.231e+00  5.793e-01 ...  5.213e+00  7.438e-01]
#      nit: 14
#      jac: [ 4.742e-04 -4.143e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5314024252823821
#        x: [ 5.244e+00  4.143e-01 ...  5.231e+00  5.793e-01]
#      nit: 14
#      jac: [ 3.431e-04 -4.154e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5314472526869538
#        x: [ 5.252e+00  2.491e-01 ...  5.244e+00  4.143e-01]
#      nit: 14
#      jac: [ 2.119e-04 -4.161e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5314876022857957
#        x: [ 5.255e+00  8.389e-02 ...  5.252e+00  2.491e-01]
#      nit: 14
#      jac: [ 8.059e-05 -4.163e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5315239215965892
#        x: [ 5.253e+00 -8.128e-02 ...  5.255e+00  8.389e-02]
#      nit: 14
#      jac: [-5.060e-05 -4.162e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5315566127598037
#        x: [ 5.245e+00 -2.462e-01 ...  5.253e+00 -8.128e-02]
#      nit: 14
#      jac: [-1.816e-04 -4.156e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5315860381555029
#        x: [ 5.232e+00 -4.107e-01 ...  5.245e+00 -2.462e-01]
#      nit: 14
#      jac: [-3.122e-04 -4.147e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316125232692992
#        x: [ 5.214e+00 -5.746e-01 ...  5.232e+00 -4.107e-01]
#      nit: 14
#      jac: [-4.424e-04 -4.133e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316363615216805
#        x: [ 5.191e+00 -7.379e-01 ...  5.214e+00 -5.746e-01]
#      nit: 14
#      jac: [-5.720e-04 -4.115e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316578165787157
#        x: [ 5.163e+00 -9.002e-01 ...  5.191e+00 -7.379e-01]
#      nit: 14
#      jac: [-7.009e-04 -4.093e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316771258075267
#        x: [ 5.130e+00 -1.061e+00 ...  5.163e+00 -9.002e-01]
#      nit: 14
#      jac: [-8.290e-04 -4.067e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.531694502908898
#        x: [ 5.091e+00 -1.222e+00 ...  5.130e+00 -1.061e+00]
#      nit: 14
#      jac: [-9.561e-04 -4.037e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5317101402433474
#        x: [ 5.048e+00 -1.380e+00 ...  5.091e+00 -1.222e+00]
#      nit: 14
#      jac: [-1.082e-03 -4.003e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5317242106602972
#        x: [ 5.000e+00 -1.537e+00 ...  5.048e+00 -1.380e+00]
#      nit: 14
#      jac: [-1.207e-03 -3.965e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5317368702145285
#        x: [ 4.947e+00 -1.693e+00 ...  5.000e+00 -1.537e+00]
#      nit: 14
#      jac: [-1.330e-03 -3.924e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5317482590237356
#        x: [ 4.889e+00 -1.847e+00 ...  4.947e+00 -1.693e+00]
#      nit: 14
#      jac: [-1.452e-03 -3.878e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5317585031105526
#        x: [ 4.826e+00 -1.998e+00 ...  4.889e+00 -1.847e+00]
#      nit: 14
#      jac: [-1.573e-03 -3.829e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5317677164444952
#        x: [ 4.759e+00 -2.148e+00 ...  4.826e+00 -1.998e+00]
#      nit: 14
#      jac: [-1.692e-03 -3.776e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5317760011361768
#        x: [ 4.687e+00 -2.295e+00 ...  4.759e+00 -2.148e+00]
#      nit: 14
#      jac: [-1.809e-03 -3.719e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5317834493616507
#        x: [ 4.610e+00 -2.440e+00 ...  4.687e+00 -2.295e+00]
#      nit: 14
#      jac: [-1.924e-03 -3.659e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.531790144149096
#        x: [ 4.529e+00 -2.583e+00 ...  4.610e+00 -2.440e+00]
#      nit: 14
#      jac: [-2.037e-03 -3.595e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5317961601177928
#        x: [ 4.444e+00 -2.722e+00 ...  4.529e+00 -2.583e+00]
#      nit: 14
#      jac: [-2.148e-03 -3.527e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318015642541768
#        x: [ 4.354e+00 -2.859e+00 ...  4.444e+00 -2.722e+00]
#      nit: 14
#      jac: [-2.257e-03 -3.456e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318064176005216
#        x: [ 4.260e+00 -2.993e+00 ...  4.354e+00 -2.859e+00]
#      nit: 14
#      jac: [-2.363e-03 -3.382e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.531810774258692
#        x: [ 4.162e+00 -3.124e+00 ...  4.260e+00 -2.993e+00]
#      nit: 14
#      jac: [-2.467e-03 -3.305e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318146835675104
#        x: [ 4.060e+00 -3.252e+00 ...  4.162e+00 -3.124e+00]
#      nit: 14
#      jac: [-2.568e-03 -3.224e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318181899710166
#        x: [ 3.954e+00 -3.376e+00 ...  4.060e+00 -3.252e+00]
#      nit: 14
#      jac: [-2.667e-03 -3.140e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318213328865156
#        x: [ 3.844e+00 -3.497e+00 ...  3.954e+00 -3.376e+00]
#      nit: 14
#      jac: [-2.763e-03 -3.054e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.531824148276404
#        x: [ 3.730e+00 -3.614e+00 ...  3.844e+00 -3.497e+00]
#      nit: 14
#      jac: [-2.856e-03 -2.964e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318266687719434
#        x: [ 3.613e+00 -3.728e+00 ...  3.730e+00 -3.614e+00]
#      nit: 14
#      jac: [-2.947e-03 -2.871e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318289233045788
#        x: [ 3.493e+00 -3.838e+00 ...  3.613e+00 -3.728e+00]
#      nit: 14
#      jac: [-3.034e-03 -2.776e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318310521950034
#        x: [ 3.369e+00 -3.944e+00 ...  3.493e+00 -3.838e+00]
#      nit: 14
#      jac: [-3.118e-03 -2.678e-03 ...  0.000e+00  0.000e+00]
#     nfev: 292
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318329291935875
#        x: [ 3.242e+00 -4.046e+00 ...  3.369e+00 -3.944e+00]
#      nit: 14
#      jac: [-3.199e-03 -2.578e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318345102574411
#        x: [ 3.112e+00 -4.144e+00 ...  3.242e+00 -4.046e+00]
#      nit: 14
#      jac: [-3.277e-03 -2.475e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318359525781803
#        x: [ 2.979e+00 -4.237e+00 ...  3.112e+00 -4.144e+00]
#      nit: 14
#      jac: [-3.352e-03 -2.369e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318372045222137
#        x: [ 2.843e+00 -4.327e+00 ...  2.979e+00 -4.237e+00]
#      nit: 14
#      jac: [-3.423e-03 -2.262e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318383156517462
#        x: [ 2.704e+00 -4.412e+00 ...  2.843e+00 -4.327e+00]
#      nit: 14
#      jac: [-3.491e-03 -2.152e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318392996452714
#        x: [ 2.563e+00 -4.493e+00 ...  2.704e+00 -4.412e+00]
#      nit: 14
#      jac: [-3.555e-03 -2.040e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318401690897008
#        x: [ 2.419e+00 -4.569e+00 ...  2.563e+00 -4.493e+00]
#      nit: 14
#      jac: [-3.616e-03 -1.927e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318409350850528
#        x: [ 2.274e+00 -4.640e+00 ...  2.419e+00 -4.569e+00]
#      nit: 14
#      jac: [-3.673e-03 -1.812e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318416079561168
#        x: [ 2.126e+00 -4.707e+00 ...  2.274e+00 -4.640e+00]
#      nit: 14
#      jac: [-3.726e-03 -1.694e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318421967777018
#        x: [ 1.976e+00 -4.769e+00 ...  2.126e+00 -4.707e+00]
#      nit: 14
#      jac: [-3.776e-03 -1.576e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318427096606214
#        x: [ 1.824e+00 -4.827e+00 ...  1.976e+00 -4.769e+00]
#      nit: 14
#      jac: [-3.822e-03 -1.456e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318431543065147
#        x: [ 1.671e+00 -4.880e+00 ...  1.824e+00 -4.827e+00]
#      nit: 14
#      jac: [-3.864e-03 -1.334e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318435371465019
#        x: [ 1.516e+00 -4.927e+00 ...  1.671e+00 -4.880e+00]
#      nit: 14
#      jac: [-3.902e-03 -1.212e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318438644869463
#        x: [ 1.360e+00 -4.970e+00 ...  1.516e+00 -4.927e+00]
#      nit: 14
#      jac: [-3.936e-03 -1.088e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318441414509385
#        x: [ 1.203e+00 -5.008e+00 ...  1.360e+00 -4.970e+00]
#      nit: 14
#      jac: [-3.967e-03 -9.635e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318443732628039
#        x: [ 1.044e+00 -5.041e+00 ...  1.203e+00 -5.008e+00]
#      nit: 14
#      jac: [-3.993e-03 -8.380e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318445641610219
#        x: [ 8.851e-01 -5.069e+00 ...  1.044e+00 -5.041e+00]
#      nit: 14
#      jac: [-4.015e-03 -7.119e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318447182848021
#        x: [ 7.251e-01 -5.092e+00 ...  8.851e-01 -5.069e+00]
#      nit: 14
#      jac: [-4.034e-03 -5.851e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318448390850696
#        x: [ 5.645e-01 -5.110e+00 ...  7.251e-01 -5.092e+00]
#      nit: 14
#      jac: [-4.048e-03 -4.579e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318449299820347
#        x: [ 4.035e-01 -5.123e+00 ...  5.645e-01 -5.110e+00]
#      nit: 14
#      jac: [-4.059e-03 -3.304e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318449939713549
#        x: [ 2.423e-01 -5.130e+00 ...  4.035e-01 -5.123e+00]
#      nit: 14
#      jac: [-4.065e-03 -2.026e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318450350756725
#        x: [ 8.101e-02 -5.133e+00 ...  2.423e-01 -5.130e+00]
#      nit: 14
#      jac: [-4.068e-03 -7.477e-05 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318450562546406
#        x: [-8.022e-02 -5.130e+00 ...  8.101e-02 -5.133e+00]
#      nit: 14
#      jac: [-4.066e-03  5.302e-05 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318450591918022
#        x: [-2.412e-01 -5.123e+00 ... -8.022e-02 -5.130e+00]
#      nit: 14
#      jac: [-4.061e-03  1.806e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318450464470861
#        x: [-4.018e-01 -5.111e+00 ... -2.412e-01 -5.123e+00]
#      nit: 14
#      jac: [-4.051e-03  3.079e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.531845019184904
#        x: [-5.619e-01 -5.093e+00 ... -4.018e-01 -5.111e+00]
#      nit: 14
#      jac: [-4.038e-03  4.348e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318449787234732
#        x: [-7.212e-01 -5.070e+00 ... -5.619e-01 -5.093e+00]
#      nit: 14
#      jac: [-4.020e-03  5.612e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318449262389321
#        x: [-8.797e-01 -5.043e+00 ... -7.212e-01 -5.070e+00]
#      nit: 14
#      jac: [-3.999e-03  6.869e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318448626695683
#        x: [-1.037e+00 -5.010e+00 ... -8.797e-01 -5.043e+00]
#      nit: 14
#      jac: [-3.973e-03  8.118e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318447888880621
#        x: [-1.194e+00 -4.973e+00 ... -1.037e+00 -5.010e+00]
#      nit: 14
#      jac: [-3.944e-03  9.357e-04 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318447057359572
#        x: [-1.349e+00 -4.931e+00 ... -1.194e+00 -4.973e+00]
#      nit: 14
#      jac: [-3.911e-03  1.059e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318446134247338
#        x: [-1.502e+00 -4.884e+00 ... -1.349e+00 -4.931e+00]
#      nit: 14
#      jac: [-3.874e-03  1.180e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.531844512429332
#        x: [-1.654e+00 -4.832e+00 ... -1.502e+00 -4.884e+00]
#      nit: 14
#      jac: [-3.833e-03  1.301e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318444033194744
#        x: [-1.804e+00 -4.775e+00 ... -1.654e+00 -4.832e+00]
#      nit: 14
#      jac: [-3.788e-03  1.420e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318442868550546
#        x: [-1.952e+00 -4.714e+00 ... -1.804e+00 -4.775e+00]
#      nit: 14
#      jac: [-3.740e-03  1.538e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318441635490321
#        x: [-2.098e+00 -4.648e+00 ... -1.952e+00 -4.714e+00]
#      nit: 14
#      jac: [-3.688e-03  1.653e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318440342185888
#        x: [-2.242e+00 -4.578e+00 ... -2.098e+00 -4.648e+00]
#      nit: 14
#      jac: [-3.633e-03  1.768e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318438990664303
#        x: [-2.384e+00 -4.503e+00 ... -2.242e+00 -4.578e+00]
#      nit: 14
#      jac: [-3.574e-03  1.880e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.531843759066911
#        x: [-2.523e+00 -4.424e+00 ... -2.384e+00 -4.503e+00]
#      nit: 14
#      jac: [-3.511e-03  1.990e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318436144024203
#        x: [-2.659e+00 -4.340e+00 ... -2.523e+00 -4.424e+00]
#      nit: 14
#      jac: [-3.445e-03  2.099e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318434655010614
#        x: [-2.793e+00 -4.253e+00 ... -2.659e+00 -4.340e+00]
#      nit: 14
#      jac: [-3.376e-03  2.205e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318433127274482
#        x: [-2.924e+00 -4.161e+00 ... -2.793e+00 -4.253e+00]
#      nit: 14
#      jac: [-3.304e-03  2.309e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318431566063503
#        x: [-3.052e+00 -4.065e+00 ... -2.924e+00 -4.161e+00]
#      nit: 14
#      jac: [-3.228e-03  2.410e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318429972244196
#        x: [-3.176e+00 -3.965e+00 ... -3.052e+00 -4.065e+00]
#      nit: 14
#      jac: [-3.149e-03  2.509e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.531842834928753
#        x: [-3.298e+00 -3.862e+00 ... -3.176e+00 -3.965e+00]
#      nit: 14
#      jac: [-3.068e-03  2.606e-03 ...  0.000e+00  0.000e+00]
#     nfev: 295
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5318426700386102
#        x: [-3.416e+00 -3.754e+00 ... -3.298e+00 -3.862e+00]
#      nit: 14
# ...
#     nfev: 132
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316891438699329
#        x: [ 2.608e-01 -3.308e+00 ...  3.650e-01 -3.300e+00]
#      nit: 7
#      jac: [ 1.795e-02  1.412e-03 ...  0.000e+00  0.000e+00]
#     nfev: 131
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316879450515364
#        x: [ 1.569e-01 -3.313e+00 ...  2.608e-01 -3.308e+00]
#      nit: 7
#      jac: [ 1.799e-02  8.478e-04 ...  0.000e+00  0.000e+00]
#     nfev: 132
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316864432762791
#        x: [ 5.260e-02 -3.315e+00 ...  1.569e-01 -3.313e+00]
#      nit: 7
#      jac: [ 1.801e-02  2.825e-04 ...  0.000e+00  0.000e+00]
#     nfev: 132
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316849834534946
#        x: [-5.147e-02 -3.313e+00 ...  5.260e-02 -3.315e+00]
#      nit: 7
#      jac: [ 1.801e-02 -2.833e-04 ...  0.000e+00  0.000e+00]
#     nfev: 133
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316833893014083
#        x: [-1.555e-01 -3.309e+00 ... -5.147e-02 -3.313e+00]
#      nit: 7
#      jac: [ 1.799e-02 -8.488e-04 ...  0.000e+00  0.000e+00]
#     nfev: 133
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316818835035835
#        x: [-2.592e-01 -3.301e+00 ... -1.555e-01 -3.309e+00]
#      nit: 7
#      jac: [ 1.795e-02 -1.413e-03 ...  0.000e+00  0.000e+00]
#     nfev: 133
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316805529656757
#        x: [-3.627e-01 -3.289e+00 ... -2.592e-01 -3.301e+00]
#      nit: 7
#      jac: [ 1.790e-02 -1.977e-03 ...  0.000e+00  0.000e+00]
#     nfev: 132
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316796799826742
#        x: [-4.656e-01 -3.275e+00 ... -3.627e-01 -3.289e+00]
#      nit: 7
#      jac: [ 1.783e-02 -2.538e-03 ...  0.000e+00  0.000e+00]
#     nfev: 131
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316788581576728
#        x: [-5.678e-01 -3.257e+00 ... -4.656e-01 -3.275e+00]
#      nit: 8
#      jac: [ 1.774e-02 -3.097e-03 ...  0.000e+00  0.000e+00]
#     nfev: 153
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316782165362185
#        x: [-6.697e-01 -3.236e+00 ... -5.678e-01 -3.257e+00]
#      nit: 7
#      jac: [ 1.764e-02 -3.653e-03 ...  0.000e+00  0.000e+00]
#     nfev: 131
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316792129101623
#        x: [-7.710e-01 -3.212e+00 ... -6.697e-01 -3.236e+00]
#      nit: 6
#      jac: [-2.552e-03  6.050e-04 ...  0.000e+00  0.000e+00]
#     nfev: 113
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316792428677004
#        x: [-8.700e-01 -3.185e+00 ... -7.710e-01 -3.212e+00]
#      nit: 6
#      jac: [ 1.738e-02 -4.754e-03 ...  0.000e+00  0.000e+00]
#     nfev: 112
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316782205453123
#        x: [-9.698e-01 -3.154e+00 ... -8.700e-01 -3.185e+00]
#      nit: 7
#      jac: [ 1.722e-02 -5.298e-03 ...  0.000e+00  0.000e+00]
#     nfev: 132
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.531677409262343
#        x: [-1.068e+00 -3.121e+00 ... -9.698e-01 -3.154e+00]
#      nit: 8
#      jac: [ 1.705e-02 -5.837e-03 ...  0.000e+00  0.000e+00]
#     nfev: 155
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316769162801223
#        x: [-1.165e+00 -3.084e+00 ... -1.068e+00 -3.121e+00]
#      nit: 7
#      jac: [-2.451e-03  9.186e-04 ...  0.000e+00  0.000e+00]
#     nfev: 135
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316765970508958
#        x: [-1.260e+00 -3.045e+00 ... -1.165e+00 -3.084e+00]
#      nit: 7
#      jac: [-2.420e-03  9.947e-04 ...  0.000e+00  0.000e+00]
#     nfev: 127
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316813550061912
#        x: [-1.354e+00 -3.002e+00 ... -1.260e+00 -3.045e+00]
#      nit: 5
#      jac: [-2.387e-03  1.069e-03 ...  0.000e+00  0.000e+00]
#     nfev: 91
#     njev: 5
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316864423695562
#        x: [-1.448e+00 -2.956e+00 ... -1.354e+00 -3.002e+00]
#      nit: 7
#      jac: [ 1.618e-02 -7.929e-03 ...  0.000e+00  0.000e+00]
#     nfev: 132
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.531672714056592
#        x: [-1.539e+00 -2.908e+00 ... -1.448e+00 -2.956e+00]
#      nit: 7
#      jac: [-2.313e-03  1.216e-03 ...  0.000e+00  0.000e+00]
#     nfev: 127
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316727047330602
#        x: [-1.629e+00 -2.857e+00 ... -1.539e+00 -2.908e+00]
#      nit: 7
#      jac: [-2.272e-03  1.288e-03 ...  0.000e+00  0.000e+00]
#     nfev: 126
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316726370793609
#        x: [-1.717e+00 -2.804e+00 ... -1.629e+00 -2.857e+00]
#      nit: 6
#      jac: [ 1.537e-02 -9.418e-03 ...  0.000e+00  0.000e+00]
#     nfev: 112
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.531673493137067
#        x: [-1.804e+00 -2.746e+00 ... -1.717e+00 -2.804e+00]
#      nit: 6
#      jac: [-2.185e-03  1.426e-03 ...  0.000e+00  0.000e+00]
#     nfev: 113
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316747488776336
#        x: [-1.888e+00 -2.688e+00 ... -1.804e+00 -2.746e+00]
#      nit: 7
#      jac: [-2.138e-03  1.494e-03 ...  0.000e+00  0.000e+00]
#     nfev: 126
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316753590857444
#        x: [-1.971e+00 -2.626e+00 ... -1.888e+00 -2.688e+00]
#      nit: 7
#      jac: [-2.089e-03  1.559e-03 ...  0.000e+00  0.000e+00]
#     nfev: 126
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316754700913958
#        x: [-2.051e+00 -2.561e+00 ... -1.971e+00 -2.626e+00]
#      nit: 6
#      jac: [ 1.407e-02 -1.127e-02 ...  0.000e+00  0.000e+00]
#     nfev: 112
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316754203340803
#        x: [-2.130e+00 -2.494e+00 ... -2.051e+00 -2.561e+00]
#      nit: 7
#      jac: [-1.985e-03  1.686e-03 ...  0.000e+00  0.000e+00]
#     nfev: 126
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316753072092015
#        x: [-2.206e+00 -2.425e+00 ... -2.130e+00 -2.494e+00]
#      nit: 6
#      jac: [ 1.334e-02 -1.213e-02 ...  0.000e+00  0.000e+00]
#     nfev: 112
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.531675054721903
#        x: [-2.280e+00 -2.353e+00 ... -2.206e+00 -2.425e+00]
#      nit: 7
#      jac: [-1.874e-03  1.806e-03 ...  0.000e+00  0.000e+00]
#     nfev: 126
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316751872223429
#        x: [-2.351e+00 -2.280e+00 ... -2.280e+00 -2.353e+00]
#      nit: 7
#      jac: [-1.815e-03  1.863e-03 ...  0.000e+00  0.000e+00]
#     nfev: 127
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.531674600123784
#        x: [-2.421e+00 -2.204e+00 ... -2.351e+00 -2.280e+00]
#      nit: 6
#      jac: [ 1.214e-02 -1.334e-02 ...  0.000e+00  0.000e+00]
#     nfev: 111
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316738768105879
#        x: [-2.488e+00 -2.126e+00 ... -2.421e+00 -2.204e+00]
#      nit: 6
#      jac: [ 1.171e-02 -1.371e-02 ...  0.000e+00  0.000e+00]
#     nfev: 113
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316730809431411
#        x: [-2.552e+00 -2.045e+00 ... -2.488e+00 -2.126e+00]
#      nit: 6
#      jac: [ 1.128e-02 -1.407e-02 ...  0.000e+00  0.000e+00]
#     nfev: 111
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316723926828097
#        x: [-2.614e+00 -1.963e+00 ... -2.552e+00 -2.045e+00]
#      nit: 6
#      jac: [ 1.083e-02 -1.442e-02 ...  0.000e+00  0.000e+00]
#     nfev: 112
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316714097700721
#        x: [-2.673e+00 -1.879e+00 ... -2.614e+00 -1.963e+00]
#      nit: 6
#      jac: [ 1.037e-02 -1.476e-02 ...  0.000e+00  0.000e+00]
#     nfev: 112
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316704568388049
#        x: [-2.729e+00 -1.794e+00 ... -2.673e+00 -1.879e+00]
#      nit: 6
#      jac: [ 9.903e-03 -1.508e-02 ...  0.000e+00  0.000e+00]
#     nfev: 113
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316693777047597
#        x: [-2.783e+00 -1.706e+00 ... -2.729e+00 -1.794e+00]
#      nit: 6
#      jac: [ 9.425e-03 -1.538e-02 ...  0.000e+00  0.000e+00]
#     nfev: 113
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316683528859917
#        x: [-2.834e+00 -1.617e+00 ... -2.783e+00 -1.706e+00]
#      nit: 6
#      jac: [ 8.937e-03 -1.567e-02 ...  0.000e+00  0.000e+00]
#     nfev: 113
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316673485351664
#        x: [-2.882e+00 -1.527e+00 ... -2.834e+00 -1.617e+00]
#      nit: 6
#      jac: [ 8.441e-03 -1.594e-02 ...  0.000e+00  0.000e+00]
#     nfev: 113
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316665135782912
#        x: [-2.927e+00 -1.435e+00 ... -2.882e+00 -1.527e+00]
#      nit: 6
#      jac: [ 7.937e-03 -1.620e-02 ...  0.000e+00  0.000e+00]
#     nfev: 112
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316660767343159
#        x: [-2.970e+00 -1.341e+00 ... -2.927e+00 -1.435e+00]
#      nit: 6
#      jac: [ 7.424e-03 -1.644e-02 ...  0.000e+00  0.000e+00]
#     nfev: 111
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.531666423125877
#        x: [-3.009e+00 -1.247e+00 ... -2.970e+00 -1.341e+00]
#      nit: 7
#      jac: [-9.964e-04  2.387e-03 ...  0.000e+00  0.000e+00]
#     nfev: 126
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316663081704459
#        x: [-3.045e+00 -1.152e+00 ... -3.009e+00 -1.247e+00]
#      nit: 7
#      jac: [ 6.378e-03 -1.688e-02 ...  0.000e+00  0.000e+00]
#     nfev: 134
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316654523618491
#        x: [-3.078e+00 -1.054e+00 ... -3.045e+00 -1.152e+00]
#      nit: 6
#      jac: [ 5.845e-03 -1.707e-02 ...  0.000e+00  0.000e+00]
#     nfev: 113
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316657468763344
#        x: [-3.108e+00 -9.565e-01 ... -3.078e+00 -1.054e+00]
#      nit: 7
#      jac: [-7.662e-04  2.466e-03 ...  0.000e+00  0.000e+00]
#     nfev: 126
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.531667589535527
#        x: [-3.136e+00 -8.580e-01 ... -3.108e+00 -9.565e-01]
#      nit: 6
#      jac: [-6.883e-04  2.488e-03 ...  0.000e+00  0.000e+00]
#     nfev: 106
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316701847674443
#        x: [-3.159e+00 -7.591e-01 ... -3.136e+00 -8.580e-01]
#      nit: 6
#      jac: [-6.097e-04  2.507e-03 ...  0.000e+00  0.000e+00]
#     nfev: 106
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316728403655249
#        x: [-3.180e+00 -6.592e-01 ... -3.159e+00 -7.591e-01]
#      nit: 6
#      jac: [-5.304e-04  2.524e-03 ...  0.000e+00  0.000e+00]
#     nfev: 106
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316755237589607
#        x: [-3.198e+00 -5.587e-01 ... -3.180e+00 -6.592e-01]
#      nit: 6
#      jac: [-4.506e-04  2.538e-03 ...  0.000e+00  0.000e+00]
#     nfev: 106
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316780623747951
#        x: [-3.212e+00 -4.577e-01 ... -3.198e+00 -5.587e-01]
#      nit: 6
#      jac: [-3.705e-04  2.550e-03 ...  0.000e+00  0.000e+00]
#     nfev: 106
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316804384209812
#        x: [-3.224e+00 -3.565e-01 ... -3.212e+00 -4.577e-01]
#      nit: 6
#      jac: [-2.900e-04  2.559e-03 ...  0.000e+00  0.000e+00]
#     nfev: 106
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316826770927582
#        x: [-3.232e+00 -2.549e-01 ... -3.224e+00 -3.565e-01]
#      nit: 6
#      jac: [-2.094e-04  2.566e-03 ...  0.000e+00  0.000e+00]
#     nfev: 106
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316847930141031
#        x: [-3.236e+00 -1.532e-01 ... -3.232e+00 -2.549e-01]
#      nit: 6
#      jac: [-1.286e-04  2.570e-03 ...  0.000e+00  0.000e+00]
#     nfev: 106
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316867956887508
#        x: [-3.238e+00 -5.143e-02 ... -3.236e+00 -1.532e-01]
#      nit: 6
#      jac: [-4.779e-05  2.571e-03 ...  0.000e+00  0.000e+00]
#     nfev: 106
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316886936781869
#        x: [-3.237e+00  5.029e-02 ... -3.238e+00 -5.143e-02]
#      nit: 6
#      jac: [ 3.300e-05  2.570e-03 ...  0.000e+00  0.000e+00]
#     nfev: 106
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316892585952274
#        x: [-3.232e+00  1.514e-01 ... -3.237e+00  5.029e-02]
#      nit: 6
#      jac: [ 1.139e-04  2.567e-03 ...  0.000e+00  0.000e+00]
#     nfev: 107
#     njev: 6
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.5316879060550658
#        x: [-3.224e+00  2.528e-01 ... -3.232e+00  1.514e-01]
#      nit: 7
#      jac: [-1.417e-03 -1.800e-02 ...  0.000e+00  0.000e+00]
#     nfev: 135
#     njev: 7
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.531685945484716
#        x: [-3.213e+00  3.543e-01 ... -3.224e+00  2.528e-01]
#      nit: 8
#      jac: [-1.982e-03 -1.795e-02 ...  0.000e+00  0.000e+00]
#     nfev: 154
#     njev: 8

# %%
plot_componentes(evolucao_1, evolucao_2, 1)

# Controlabilidade da equação de lindblad, heisenberg
