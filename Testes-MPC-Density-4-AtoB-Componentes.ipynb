# %%
# Bilbiotecas para auxílio na programação matemática
import math, sys 
import numpy as np
import sympy as sp
import cmath
import time

from scipy import sparse # Produção das diagonais das matrizes
from scipy.sparse import diags 
from scipy.linalg import expm

# Plotagem 2D e 3D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm


from os import path # Suficiente para manipulação de arquivos
    
# Para solução exata
from scipy.special import hermite
from math import factorial

# %matplotlib inline
count = 0

# Para otimização dos sistemas
from scipy import optimize
from random import randint, uniform, random

# %%
# Manipulação das matrizes, soma e subtração

def somar(A, B):
    C = []
    num_linhas_a = len(A)
    num_colunas_a = len(A[0])
    
    for i in range (num_linhas_a):
        linha = [0]*num_colunas_a
        C.append(linha)
        for j in range(num_colunas_a):
            C[i][j] = A[i][j] + B[i][j]

    return C

def sub(A, B):
    C = []
    num_linhas_a = len(A)
    num_colunas_a = len(A[0])
    
    for i in range (num_linhas_a):
        linha = [0]*num_colunas_a
        C.append(linha)
        for j in range(num_linhas_a):
            C[i][j] = A[i][j] - B[i][j]

    return C

# %%
## CONSTANTES PARA O CONTROLADOR

# Considerações: constante de Planck verdadeira: 1, massa: 1

TEMPO_ANALISE = 10 
QUANTIDADE_PONTOS_AMOSTRAGEM = 1000
PASSO = TEMPO_ANALISE/QUANTIDADE_PONTOS_AMOSTRAGEM

MIN_HORIZONTE = 3 # Horizonte mínimo da análise
MAX_HORIZONTE = 30 # Horizonte máximo da análise

# Com horizonte em 10, a avaliação dura em torno de 80 minutos 

DESEJADO = [[1.00],[0.00]] # [[c1];[c2]] = [[0.707],[-0.707]]
RHO_DESEJADO = np.matmul(DESEJADO, np.transpose(DESEJADO))

# Determinação dos valores de início e fim da análise
num = PASSO
contador = 0
while num < 1:
    num *= 10
    contador += 1

EXPOENTE = contador
INICIO_ANALISE = 0*10**(-EXPOENTE) # Tempo inicial da analise em um horizonte
FINAL_ANALISE = (1*10**(-EXPOENTE))+PASSO # Tempo final da analise em um horizonte

# %%
## CONSTANTES PARA O ALGORITMO GENÉTICO

ELITISMO = True
PORCENTAGEM_ELITISMO = 0.20

TAMANHO_POP = 50
TAXA_MUTACAO = 0.10
TAXA_CRUZAMENTO = 0.70
GERACOES = 100

# Valores mínimos e máximos para gerar uma população
MIN = -5
MAX = 5

# %%
def dpsi_dt(t, ro, H): # A derivada da ro em relação ao tempo não tem dependência temporal
    A = np.zeros((2,2), dtype=np.complex_)
    A = (np.dot(H,ro))-(np.dot(ro, H)) # [H,p]
    return -1j*A

# Runge-Kutta de quarta ordem

def runge_kutta(onda, fator_runge_kutta, hamiltoniano, tempo_inicial = 0):

    k1 = dpsi_dt(tempo_inicial, onda, hamiltoniano)
    k2 = dpsi_dt(tempo_inicial + 0.5 * fator_runge_kutta, somar(onda, np.dot((0.5*fator_runge_kutta), k1)), hamiltoniano)
    k3 = dpsi_dt(tempo_inicial + 0.5 * fator_runge_kutta, somar(onda, np.dot((0.5*fator_runge_kutta), k2)), hamiltoniano)
    k4 = dpsi_dt(tempo_inicial + fator_runge_kutta, somar(onda, np.dot(fator_runge_kutta, k3)), hamiltoniano)
    
    ## y(i+1) = y(i) + h/6*(k1+2*k2+2*k3+k4)
    
    A = somar(np.dot(2,k3), k4)
    B = somar(np.dot(2,k2), k1)
    C = somar(A, B)

    runge = somar(onda,np.dot((fator_runge_kutta / 6.0),(C)))
    
    return runge

# %%
def func_objetivo(vetor_controles, tempo_atual, rho_desejado, 
                  rho_atual, H, horizonte, fator_runge_kutta):
    
    fo = 0
    pos = 0
    
    tempo_inicial = INICIO_ANALISE
    tempo_final = FINAL_ANALISE
    
    controles = np.zeros((2,2), dtype=np.complex_)
    controles = [[0, complex(vetor_controles[0], vetor_controles[1])], 
                 [complex(vetor_controles[0], -vetor_controles[1]), 0]]
    
    matriz_inicial = rho_atual

    matriz_desejada = np.zeros((2,2),dtype=np.complex_)
    hamiltoniano = H

    H = [[np.exp(-1j*np.pi*tempo_atual/2),0],[0,np.exp(1j*np.pi*tempo_atual/2)]]
    U = H
    U = np.asmatrix(U)
    U_dagger = U.getH()
    teste = np.dot(np.dot(U,rho_desejado),U_dagger)
    matriz_desejada = np.squeeze(np.asarray(teste))

    matriz_teste = sub(matriz_inicial, matriz_desejada)
    
    teste = []
    for m in range(0, 2):
        teste.append(abs(matriz_teste[0][m])+abs(matriz_teste[0][m]))
    
    fo += max(teste)

    runge = runge_kutta(matriz_inicial, fator_runge_kutta, 
                        somar(hamiltoniano, controles), tempo_inicial = tempo_inicial)

    matriz_inicial = runge

    tempo_inicial = round(tempo_inicial+PASSO, EXPOENTE)
    tempo_final = round(tempo_final+PASSO, EXPOENTE)
    tempo = round(tempo_atual+PASSO, EXPOENTE)
    pos += 2

    while horizonte > 1:
        
        H = [[np.exp(-1j*np.pi*tempo/2),0],[0,np.exp(1j*np.pi*tempo/2)]]
        U = H
        U = np.asmatrix(U)
        U_dagger = U.getH()
        teste = np.dot(np.dot(U,rho_desejado),U_dagger)
        matriz_desejada = np.squeeze(np.asarray(teste))
        
        teste = []
        for m in range(0, 2):
            teste.append(abs(matriz_teste[0][m])+abs(matriz_teste[0][m]))

        matriz_teste = sub(matriz_inicial, matriz_desejada)
        
        fo += max(teste)
        
        controles = [[0, complex(vetor_controles[pos], vetor_controles[pos+1])], 
                     [complex(vetor_controles[pos], -vetor_controles[pos+1]), 0]]

        runge = runge_kutta(matriz_inicial, fator_runge_kutta, 
                        somar(hamiltoniano, controles), tempo_inicial = tempo_inicial)

        matriz_inicial = runge

        tempo_inicial = round(tempo_inicial+PASSO, EXPOENTE)
        tempo_final = round(tempo_final+PASSO, EXPOENTE)
        tempo = round(tempo_atual+PASSO, EXPOENTE)
        horizonte -= 1

    return fo

# %%
def main(horizonte, rho_inicial):
    
    u = [] # Controles 
    for i in range(0, 2*horizonte):
        u.append(uniform(-5,5))

    evolucao_1 = np.zeros((2,QUANTIDADE_PONTOS_AMOSTRAGEM), dtype=np.complex_)
    evolucao_2 = np.zeros((2,QUANTIDADE_PONTOS_AMOSTRAGEM), dtype=np.complex_)
        
    # O que será retornado por essa função
    
    vetor_controles = np.zeros((1, QUANTIDADE_PONTOS_AMOSTRAGEM), dtype=np.complex_) # Valores de controle
    constantes = np.zeros((2, QUANTIDADE_PONTOS_AMOSTRAGEM), dtype=np.complex_) # Para verificar se as integrais estão resultando em 1
    valores_onda = np.zeros((2, QUANTIDADE_PONTOS_AMOSTRAGEM), dtype=np.complex_)
    
    H = np.zeros((2,2), dtype=np.complex_)
    H = [[(3/2*np.pi), 0], [0, (1/2*np.pi)]]
    
    tempo = 0
    pos = 0
    while tempo < TEMPO_ANALISE:

        evolucao_1[0][pos] = rho_inicial[0][0]
        evolucao_1[1][pos] = rho_inicial[1][1]

        evolucao_2[0][pos] = rho_inicial[0][1]
        evolucao_2[1][pos] = rho_inicial[1][0]
    
        resultado = optimize.minimize(func_objetivo, u, args=(tempo, RHO_DESEJADO, rho_inicial, H, horizonte, PASSO), method='SLSQP')

        print('------------------')
        print(resultado)
        
        controle = np.zeros((2,2), dtype=np.complex_)
        controle = [[0, complex(resultado.x[0], resultado.x[1])],[complex(resultado.x[0], -resultado.x[1]), 0]]
        H = somar(H, controle)
    
        ## Adaptação da onda ao controle
        
        rho_avancado = runge_kutta(rho_inicial, PASSO, H, tempo_inicial = INICIO_ANALISE)
        rho_inicial = rho_avancado
        
        # Reset
        H = [[(3/2*np.pi), 0], [0, (1/2*np.pi)]]
    
        u = [] # Controles 
        for i in range(0, 2*horizonte):
            u.append(resultado.x[0])
            u.append(resultado.x[1])
        
        pos += 1
        tempo = round(tempo+PASSO, EXPOENTE)

    return evolucao_1, evolucao_2

# %%
# Plotagem 2D e 3D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm

def plot_componentes(valores_onda,  evolucao_d, componente):
    
    ts1 = np.linspace(0, TEMPO_ANALISE, QUANTIDADE_PONTOS_AMOSTRAGEM)
    ts2 = np.linspace(0, TEMPO_ANALISE, QUANTIDADE_PONTOS_AMOSTRAGEM)
    
    real_primeiro = [elemento.real for elemento in valores_onda[componente-1]]
    imaginario_primeiro = [elemento.imag for elemento in valores_onda[componente-1]]
    
    real_segundo = [elemento.real for elemento in evolucao_d[componente-1]]
    imaginario_segundo = [elemento.imag for elemento in evolucao_d[componente-1]]
    
    # Plotagem
    plt.subplot(2,1,1)

    plt.ylabel('Pesos') 
    plt.xlabel('Tempo') 
    plt.title(f"{componente}ª componente -> real")
    plt.plot(ts1, real_primeiro, color='r', marker='*', linewidth=1, markersize=1, label="primeiro")
    plt.plot(ts2, real_segundo, color='b', marker='o',  linewidth=1, markersize=1, label="segundo")
    plt.legend(loc='upper right')
    
    plt.subplot(2,1,2)

    plt.ylabel('Imaginário') 
    plt.xlabel('Tempo') 
    plt.title(f"{componente}ª componente -> imaginária")
    plt.plot(ts1, imaginario_primeiro, color='r', marker='*', linewidth=1, markersize=1, label="primeiro")
    plt.plot(ts2, imaginario_segundo, color='b', marker='o',  linewidth=1, markersize=1, label="segundo")
    plt.legend(loc='upper right')

    plt.axis([0,TEMPO_ANALISE,0,1])

    plt.tight_layout()

# %%
PSI = np.ones((2,1), dtype=np.complex_)
PSI = [[0.80],[0.60]]
ro = np.matmul(PSI, np.transpose(PSI))
evolucao_1, evolucao_2 = main(4, ro)
# Out:
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 1.9955592680041274
#        x: [ 1.346e+00  6.379e+01  1.564e+00  3.259e+00  1.435e+00
#             4.022e+00 -4.909e+00 -1.039e+00]
#      nit: 34
#      jac: [ 9.113e-03  1.641e-02  1.249e-02  1.495e-02  0.000e+00
#             0.000e+00  0.000e+00  0.000e+00]
#     nfev: 350
#     njev: 34
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0974259224640609
#        x: [-3.478e-01  1.148e+00 ...  1.346e+00  6.379e+01]
#      nit: 26
#      jac: [-1.016e-04  1.441e-04 ...  0.000e+00  0.000e+00]
#     nfev: 453
#     njev: 26
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09678215881765895
#        x: [ 1.461e-01  4.123e-02 ... -3.478e-01  1.148e+00]
#      nit: 8
#      jac: [-3.472e-05 -1.809e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09676754303441482
#        x: [ 1.461e-01  4.123e-02 ...  1.461e-01  4.123e-02]
#      nit: 1
#      jac: [ 9.874e-05  1.034e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0967881077855417
#        x: [ 1.461e-01  4.123e-02 ...  1.461e-01  4.123e-02]
#      nit: 1
#      jac: [ 2.125e-04  4.122e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09684441158236101
#        x: [ 1.461e-01  4.123e-02 ...  1.461e-01  4.123e-02]
#      nit: 1
#      jac: [ 3.271e-04  6.847e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09693639834123102
#        x: [ 1.461e-01  4.123e-02 ...  1.461e-01  4.123e-02]
#      nit: 1
#      jac: [ 4.426e-04  9.210e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09706397643507247
#        x: [ 1.461e-01  4.123e-02 ...  1.461e-01  4.123e-02]
#      nit: 1
#      jac: [ 5.587e-04  1.121e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09722701878463758
#        x: [ 1.461e-01  4.123e-02 ...  1.461e-01  4.123e-02]
#      nit: 1
#      jac: [ 6.754e-04  1.285e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09742536298509408
#        x: [ 1.461e-01  4.123e-02 ...  1.461e-01  4.123e-02]
#      nit: 1
#      jac: [ 7.926e-04  1.412e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09764383869302273
#        x: [ 1.355e-01  3.939e-02 ...  1.461e-01  4.123e-02]
#      nit: 2
#      jac: [ 8.978e-04  1.480e-04 ...  0.000e+00  0.000e+00]
#     nfev: 35
#     njev: 2
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09726187928121877
#        x: [-6.990e-01 -9.169e-02 ...  1.355e-01  3.939e-02]
#      nit: 8
#      jac: [ 7.062e-05  4.202e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0970368489571507
#        x: [-6.990e-01 -9.169e-02 ... -6.990e-01 -9.169e-02]
#      nit: 1
#      jac: [-5.129e-04 -9.276e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09679681307402088
#        x: [ 1.950e-01  4.303e-02 ... -6.990e-01 -9.169e-02]
#      nit: 8
#      jac: [-2.237e-05 -2.831e-07 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09677737130669817
#        x: [ 1.950e-01  4.303e-02 ...  1.950e-01  4.303e-02]
#      nit: 1
#      jac: [ 1.370e-04  4.834e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09681952853057929
#        x: [ 1.950e-01  4.303e-02 ...  1.950e-01  4.303e-02]
#      nit: 1
#      jac: [ 2.901e-04  8.000e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09692403925660065
#        x: [ 1.950e-01  4.303e-02 ...  1.950e-01  4.303e-02]
#      nit: 1
#      jac: [ 4.441e-04  1.068e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09709079867908588
#        x: [ 1.950e-01  4.303e-02 ...  1.950e-01  4.303e-02]
#      nit: 1
#      jac: [ 5.988e-04  1.288e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09731963956798495
#        x: [ 1.950e-01  4.303e-02 ...  1.950e-01  4.303e-02]
#      nit: 1
#      jac: [ 7.541e-04  1.459e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09706901075172181
#        x: [-6.953e-01 -1.116e-01 ...  1.950e-01  4.303e-02]
#      nit: 8
#      jac: [ 2.447e-05  3.085e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0971154747254892
#        x: [-6.953e-01 -1.116e-01 ... -6.953e-01 -1.116e-01]
#      nit: 1
#      jac: [-6.724e-04 -1.254e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09687140090653279
#        x: [ 3.232e-01  6.032e-02 ... -6.953e-01 -1.116e-01]
#      nit: 8
#      jac: [-3.769e-05 -4.768e-07 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09681539543599693
#        x: [ 3.232e-01  6.032e-02 ...  3.232e-01  6.032e-02]
#      nit: 1
#      jac: [ 2.249e-04  6.582e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09692680182074631
#        x: [ 3.232e-01  6.032e-02 ...  3.232e-01  6.032e-02]
#      nit: 1
#      jac: [ 4.784e-04  1.097e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0972071977036324
#        x: [ 3.232e-01  6.032e-02 ...  3.232e-01  6.032e-02]
#      nit: 1
#      jac: [ 7.330e-04  1.457e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09701930498309141
#        x: [-5.095e-01 -8.885e-02 ...  3.232e-01  6.032e-02]
#      nit: 8
#      jac: [ 5.007e-05  5.081e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09690840121794508
#        x: [-5.095e-01 -8.885e-02 ... -5.095e-01 -8.885e-02]
#      nit: 1
#      jac: [-3.810e-04 -8.726e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09718295816080258
#        x: [-4.900e-01 -8.504e-02 ... -5.095e-01 -8.885e-02]
#      nit: 2
#      jac: [-7.574e-04 -1.464e-04 ...  0.000e+00  0.000e+00]
#     nfev: 34
#     njev: 2
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09698769153070841
#        x: [ 4.510e-01  7.950e-02 ... -4.900e-01 -8.504e-02]
#      nit: 8
#      jac: [-5.358e-05 -3.964e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09687080069707243
#        x: [ 4.510e-01  7.950e-02 ...  4.510e-01  7.950e-02]
#      nit: 1
#      jac: [ 3.079e-04  7.844e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09707947939103412
#        x: [ 4.510e-01  7.950e-02 ...  4.510e-01  7.950e-02]
#      nit: 1
#      jac: [ 6.611e-04  1.363e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09692647044242864
#        x: [-3.909e-01 -7.521e-02 ...  4.510e-01  7.950e-02]
#      nit: 8
#      jac: [ 4.479e-05  4.351e-06 ...  0.000e+00  0.000e+00]
#     nfev: 137
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09684306375886909
#        x: [-3.909e-01 -7.521e-02 ... -3.909e-01 -7.521e-02]
#      nit: 1
#      jac: [-2.721e-04 -7.291e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09700516291246886
#        x: [-3.909e-01 -7.521e-02 ... -3.909e-01 -7.521e-02]
#      nit: 1
#      jac: [-5.784e-04 -1.278e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09688607667095384
#        x: [ 3.618e-01  7.417e-02 ... -3.909e-01 -7.521e-02]
#      nit: 8
#      jac: [-3.478e-05 -3.755e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09683406602616884
#        x: [ 3.618e-01  7.417e-02 ...  3.618e-01  7.417e-02]
#      nit: 1
#      jac: [ 2.750e-04  7.354e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0969908954409906
#        x: [ 3.618e-01  7.417e-02 ...  3.618e-01  7.417e-02]
#      nit: 1
#      jac: [ 5.586e-04  1.272e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09733420425319395
#        x: [ 3.424e-01  7.011e-02 ...  3.618e-01  7.417e-02]
#      nit: 2
#      jac: [ 8.211e-04  1.672e-04 ...  0.000e+00  0.000e+00]
#     nfev: 34
#     njev: 2
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09709936406836417
#        x: [-5.451e-01 -9.705e-02 ...  3.424e-01  7.011e-02]
#      nit: 8
#      jac: [ 6.525e-05  6.303e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09692363368813495
#        x: [-5.451e-01 -9.705e-02 ... -5.451e-01 -9.705e-02]
#      nit: 1
#      jac: [-3.691e-04 -9.076e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09677284652765938
#        x: [ 1.447e-01  4.378e-02 ... -5.451e-01 -9.705e-02]
#      nit: 8
#      jac: [-1.103e-05 -1.207e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09676937127314256
#        x: [ 1.447e-01  4.378e-02 ...  1.447e-01  4.378e-02]
#      nit: 1
#      jac: [ 1.227e-04  4.737e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0968001457065244
#        x: [ 1.447e-01  4.378e-02 ...  1.447e-01  4.378e-02]
#      nit: 1
#      jac: [ 2.365e-04  7.944e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09686663460114131
#        x: [ 1.447e-01  4.378e-02 ...  1.447e-01  4.378e-02]
#      nit: 1
#      jac: [ 3.513e-04  1.079e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0969687717326142
#        x: [ 1.447e-01  4.378e-02 ...  1.447e-01  4.378e-02]
#      nit: 1
#      jac: [ 4.669e-04  1.328e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09710645537014773
#        x: [ 1.447e-01  4.378e-02 ...  1.447e-01  4.378e-02]
#      nit: 1
#      jac: [ 5.832e-04  1.540e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09727954837785524
#        x: [ 1.447e-01  4.378e-02 ...  1.447e-01  4.378e-02]
#      nit: 1
#      jac: [ 7.001e-04  1.715e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09748787835135153
#        x: [ 1.447e-01  4.378e-02 ...  1.447e-01  4.378e-02]
#      nit: 1
#      jac: [ 8.175e-04  1.854e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09716306021373655
#        x: [-7.194e-01 -1.383e-01 ...  1.447e-01  4.378e-02]
#      nit: 9
#      jac: [ 4.011e-05  5.662e-06 ...  0.000e+00  0.000e+00]
#     nfev: 155
#     njev: 9
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09710558110963707
#        x: [-7.194e-01 -1.383e-01 ... -7.194e-01 -1.383e-01]
#      nit: 1
#      jac: [-6.344e-04 -1.426e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09684713227821806
#        x: [ 2.862e-01  6.684e-02 ... -7.194e-01 -1.383e-01]
#      nit: 8
#      jac: [-3.333e-05 -1.505e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0968033911708237
#        x: [ 2.862e-01  6.684e-02 ...  2.862e-01  6.684e-02]
#      nit: 1
#      jac: [ 1.993e-04  6.951e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09689326835491618
#        x: [ 2.862e-01  6.684e-02 ...  2.862e-01  6.684e-02]
#      nit: 1
#      jac: [ 4.238e-04  1.189e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09711815955820735
#        x: [ 2.862e-01  6.684e-02 ...  2.862e-01  6.684e-02]
#      nit: 1
#      jac: [ 6.499e-04  1.612e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09742961299002784
#        x: [ 2.516e-01  5.895e-02 ...  2.862e-01  6.684e-02]
#      nit: 3
#      jac: [ 8.369e-04  1.872e-04 ...  0.000e+00  0.000e+00]
#     nfev: 54
#     njev: 3
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09715060176723145
#        x: [-6.166e-01 -1.197e-01 ...  2.516e-01  5.895e-02]
#      nit: 8
#      jac: [ 6.147e-05  7.987e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09698007603112968
#        x: [-6.166e-01 -1.197e-01 ... -6.166e-01 -1.197e-01]
#      nit: 1
#      jac: [-4.563e-04 -1.121e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09678968970004398
#        x: [ 1.784e-01  5.063e-02 ... -6.166e-01 -1.197e-01]
#      nit: 8
#      jac: [-1.962e-05 -1.550e-06 ...  0.000e+00  0.000e+00]
#     nfev: 137
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09677448827825352
#        x: [ 1.784e-01  5.063e-02 ...  1.784e-01  5.063e-02]
#      nit: 1
#      jac: [ 1.282e-04  5.245e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09681225205356747
#        x: [ 1.784e-01  5.063e-02 ...  1.784e-01  5.063e-02]
#      nit: 1
#      jac: [ 2.684e-04  9.009e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09690381995317954
#        x: [ 1.784e-01  5.063e-02 ...  1.784e-01  5.063e-02]
#      nit: 1
#      jac: [ 4.098e-04  1.233e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09704910035062442
#        x: [ 1.784e-01  5.063e-02 ...  1.784e-01  5.063e-02]
#      nit: 1
#      jac: [ 5.521e-04  1.521e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09724794787258495
#        x: [ 1.784e-01  5.063e-02 ...  1.784e-01  5.063e-02]
#      nit: 1
#      jac: [ 6.952e-04  1.763e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09750016354436064
#        x: [ 1.784e-01  5.063e-02 ...  1.784e-01  5.063e-02]
#      nit: 1
#      jac: [ 8.390e-04  1.961e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09718642027276658
#        x: [-6.394e-01 -1.291e-01 ...  1.784e-01  5.063e-02]
#      nit: 8
#      jac: [ 6.449e-05  8.881e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0969967420456741
#        x: [-6.394e-01 -1.291e-01 ... -6.394e-01 -1.291e-01]
#      nit: 1
#      jac: [-4.695e-04 -1.185e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09679141057608454
#        x: [ 1.780e-01  5.214e-02 ... -6.394e-01 -1.291e-01]
#      nit: 8
#      jac: [-2.095e-05 -1.669e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09677420819163607
#        x: [ 1.780e-01  5.214e-02 ...  1.780e-01  5.214e-02]
#      nit: 1
#      jac: [ 1.230e-04  5.326e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09681023319199089
#        x: [ 1.780e-01  5.214e-02 ...  1.780e-01  5.214e-02]
#      nit: 1
#      jac: [ 2.629e-04  9.225e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0969000857089739
#        x: [ 1.780e-01  5.214e-02 ...  1.780e-01  5.214e-02]
#      nit: 1
#      jac: [ 4.039e-04  1.268e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09704367583240292
#        x: [ 1.780e-01  5.214e-02 ...  1.780e-01  5.214e-02]
#      nit: 1
#      jac: [ 5.460e-04  1.569e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09724085988000164
#        x: [ 1.780e-01  5.214e-02 ...  1.780e-01  5.214e-02]
#      nit: 1
#      jac: [ 6.889e-04  1.826e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09749144054116976
#        x: [ 1.780e-01  5.214e-02 ...  1.780e-01  5.214e-02]
#      nit: 1
#      jac: [ 8.326e-04  2.037e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09718148027428919
#        x: [-6.344e-01 -1.350e-01 ...  1.780e-01  5.214e-02]
#      nit: 8
#      jac: [ 6.403e-05  9.552e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09699395858210003
#        x: [-6.344e-01 -1.350e-01 ... -6.344e-01 -1.350e-01]
#      nit: 1
#      jac: [-4.655e-04 -1.227e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09679098659176799
#        x: [ 1.764e-01  5.364e-02 ... -6.344e-01 -1.350e-01]
#      nit: 8
#      jac: [-2.085e-05 -1.892e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09677396011187311
#        x: [ 1.764e-01  5.364e-02 ...  1.764e-01  5.364e-02]
#      nit: 1
#      jac: [ 1.216e-04  5.420e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09680950248429698
#        x: [ 1.764e-01  5.364e-02 ...  1.764e-01  5.364e-02]
#      nit: 1
#      jac: [ 2.602e-04  9.434e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09689820276297412
#        x: [ 1.764e-01  5.364e-02 ...  1.764e-01  5.364e-02]
#      nit: 1
#      jac: [ 3.999e-04  1.302e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09703997220589278
#        x: [ 1.764e-01  5.364e-02 ...  1.764e-01  5.364e-02]
#      nit: 1
#      jac: [ 5.408e-04  1.616e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09723466897690569
#        x: [ 1.764e-01  5.364e-02 ...  1.764e-01  5.364e-02]
#      nit: 1
#      jac: [ 6.826e-04  1.885e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09748209828763454
#        x: [ 1.764e-01  5.364e-02 ...  1.764e-01  5.364e-02]
#      nit: 1
#      jac: [ 8.251e-04  2.110e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09717608078406403
#        x: [-6.288e-01 -1.406e-01 ...  1.764e-01  5.364e-02]
#      nit: 8
#      jac: [ 6.354e-05  1.015e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09699085732637958
#        x: [-6.288e-01 -1.406e-01 ... -6.288e-01 -1.406e-01]
#      nit: 1
#      jac: [-4.611e-04 -1.266e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09679049739562218
#        x: [ 1.746e-01  5.510e-02 ... -6.288e-01 -1.406e-01]
#      nit: 8
#      jac: [-2.067e-05 -2.116e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09677369020109516
#        x: [ 1.746e-01  5.510e-02 ...  1.746e-01  5.510e-02]
#      nit: 1
#      jac: [ 1.201e-04  5.507e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09680872477576297
#        x: [ 1.746e-01  5.510e-02 ...  1.746e-01  5.510e-02]
#      nit: 1
#      jac: [ 2.573e-04  9.641e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09689617855172994
#        x: [ 1.746e-01  5.510e-02 ...  1.746e-01  5.510e-02]
#      nit: 1
#      jac: [ 3.958e-04  1.334e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09703596405059356
#        x: [ 1.746e-01  5.510e-02 ...  1.746e-01  5.510e-02]
#      nit: 1
#      jac: [ 5.353e-04  1.660e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0972279414474897
#        x: [ 1.746e-01  5.510e-02 ...  1.746e-01  5.510e-02]
#      nit: 1
#      jac: [ 6.758e-04  1.943e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09747191871095895
#        x: [ 1.746e-01  5.510e-02 ...  1.746e-01  5.510e-02]
#      nit: 1
#      jac: [ 8.171e-04  2.181e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09717019590903142
#        x: [-6.229e-01 -1.462e-01 ...  1.746e-01  5.510e-02]
#      nit: 8
#      jac: [ 6.299e-05  1.073e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09698751449450782
#        x: [-6.229e-01 -1.462e-01 ... -6.229e-01 -1.462e-01]
#      nit: 1
#      jac: [-4.565e-04 -1.305e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0967897759206775
#        x: [ 1.766e-01  5.742e-02 ... -6.229e-01 -1.462e-01]
#      nit: 8
#      jac: [-1.964e-05 -2.146e-06 ...  0.000e+00  0.000e+00]
#     nfev: 137
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09677455012849201
#        x: [ 1.766e-01  5.742e-02 ...  1.766e-01  5.742e-02]
#      nit: 1
#      jac: [ 1.263e-04  5.764e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09681242069566887
#        x: [ 1.766e-01  5.742e-02 ...  1.766e-01  5.742e-02]
#      nit: 1
#      jac: [ 2.652e-04  1.006e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09690423381451874
#        x: [ 1.766e-01  5.742e-02 ...  1.766e-01  5.742e-02]
#      nit: 1
#      jac: [ 4.053e-04  1.392e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09704989761002447
#        x: [ 1.766e-01  5.742e-02 ...  1.766e-01  5.742e-02]
#      nit: 1
#      jac: [ 5.466e-04  1.734e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09724926632018493
#        x: [ 1.766e-01  5.742e-02 ...  1.766e-01  5.742e-02]
#      nit: 1
#      jac: [ 6.889e-04  2.031e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09750214044187966
#        x: [ 1.766e-01  5.742e-02 ...  1.766e-01  5.742e-02]
#      nit: 1
#      jac: [ 8.320e-04  2.283e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09718756162857023
#        x: [-6.349e-01 -1.536e-01 ...  1.766e-01  5.742e-02]
#      nit: 8
#      jac: [ 6.419e-05  1.137e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0969974194489982
#        x: [-6.349e-01 -1.536e-01 ... -6.349e-01 -1.536e-01]
#      nit: 1
#      jac: [-4.653e-04 -1.365e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09679152420143478
#        x: [ 1.762e-01  5.899e-02 ... -6.349e-01 -1.536e-01]
#      nit: 8
#      jac: [-2.089e-05 -2.488e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09677427616635814
#        x: [ 1.762e-01  5.899e-02 ...  1.762e-01  5.899e-02]
#      nit: 1
#      jac: [ 1.211e-04  5.801e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09681043485228358
#        x: [ 1.762e-01  5.899e-02 ...  1.762e-01  5.899e-02]
#      nit: 1
#      jac: [ 2.596e-04  1.024e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09690060333385442
#        x: [ 1.762e-01  5.899e-02 ...  1.762e-01  5.899e-02]
#      nit: 1
#      jac: [ 3.995e-04  1.424e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09704469138051564
#        x: [ 1.762e-01  5.899e-02 ...  1.762e-01  5.899e-02]
#      nit: 1
#      jac: [ 5.406e-04  1.779e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09724255480502775
#        x: [ 1.762e-01  5.899e-02 ...  1.762e-01  5.899e-02]
#      nit: 1
#      jac: [ 6.827e-04  2.091e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0974939956077554
#        x: [ 1.762e-01  5.899e-02 ...  1.762e-01  5.899e-02]
#      nit: 1
#      jac: [ 8.256e-04  2.357e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09718295714394776
#        x: [-6.299e-01 -1.593e-01 ...  1.762e-01  5.899e-02]
#      nit: 8
#      jac: [ 6.373e-05  1.201e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09699481178538205
#        x: [-6.299e-01 -1.593e-01 ... -6.299e-01 -1.593e-01]
#      nit: 1
#      jac: [-4.613e-04 -1.406e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09679112281576674
#        x: [ 1.745e-01  6.044e-02 ... -6.299e-01 -1.593e-01]
#      nit: 8
#      jac: [-2.080e-05 -2.697e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0967740348489381
#        x: [ 1.745e-01  6.044e-02 ...  1.745e-01  6.044e-02]
#      nit: 1
#      jac: [ 1.196e-04  5.887e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09680971705084351
#        x: [ 1.745e-01  6.044e-02 ...  1.745e-01  6.044e-02]
#      nit: 1
#      jac: [ 2.569e-04  1.044e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09689876170599598
#        x: [ 1.745e-01  6.044e-02 ...  1.745e-01  6.044e-02]
#      nit: 1
#      jac: [ 3.955e-04  1.456e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0970410797231871
#        x: [ 1.745e-01  6.044e-02 ...  1.745e-01  6.044e-02]
#      nit: 1
#      jac: [ 5.353e-04  1.824e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09723652870999344
#        x: [ 1.745e-01  6.044e-02 ...  1.745e-01  6.044e-02]
#      nit: 1
#      jac: [ 6.762e-04  2.148e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09748491311524421
#        x: [ 1.745e-01  6.044e-02 ...  1.745e-01  6.044e-02]
#      nit: 1
#      jac: [ 8.181e-04  2.427e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.097177708231589
#        x: [-6.243e-01 -1.648e-01 ...  1.745e-01  6.044e-02]
#      nit: 8
#      jac: [ 6.320e-05  1.258e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09699180093191195
#        x: [-6.243e-01 -1.648e-01 ... -6.243e-01 -1.648e-01]
#      nit: 1
#      jac: [-4.569e-04 -1.444e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09679064907776613
#        x: [ 1.727e-01  6.184e-02 ... -6.243e-01 -1.648e-01]
#      nit: 8
#      jac: [-2.064e-05 -2.891e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09677377439144785
#        x: [ 1.727e-01  6.184e-02 ...  1.727e-01  6.184e-02]
#      nit: 1
#      jac: [ 1.182e-04  5.971e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09680896788281035
#        x: [ 1.727e-01  6.184e-02 ...  1.727e-01  6.184e-02]
#      nit: 1
#      jac: [ 2.540e-04  1.063e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09689681058481603
#        x: [ 1.727e-01  6.184e-02 ...  1.727e-01  6.184e-02]
#      nit: 1
#      jac: [ 3.913e-04  1.487e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0970372146248597
#        x: [ 1.727e-01  6.184e-02 ...  1.727e-01  6.184e-02]
#      nit: 1
#      jac: [ 5.298e-04  1.867e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09723003955110365
#        x: [ 1.727e-01  6.184e-02 ...  1.727e-01  6.184e-02]
#      nit: 1
#      jac: [ 6.694e-04  2.203e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09747509247297859
#        x: [ 1.727e-01  6.184e-02 ...  1.727e-01  6.184e-02]
#      nit: 1
#      jac: [ 8.100e-04  2.496e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09717203072844849
#        x: [-6.183e-01 -1.702e-01 ...  1.727e-01  6.184e-02]
#      nit: 8
#      jac: [ 6.266e-05  1.316e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09698857433645602
#        x: [-6.183e-01 -1.702e-01 ... -6.183e-01 -1.702e-01]
#      nit: 1
#      jac: [-4.522e-04 -1.481e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09679015081896258
#        x: [ 1.708e-01  6.319e-02 ... -6.183e-01 -1.702e-01]
#      nit: 8
#      jac: [-2.047e-05 -3.099e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09677349435726645
#        x: [ 1.708e-01  6.319e-02 ...  1.708e-01  6.319e-02]
#      nit: 1
#      jac: [ 1.166e-04  6.051e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09680815545119059
#        x: [ 1.708e-01  6.319e-02 ...  1.708e-01  6.319e-02]
#      nit: 1
#      jac: [ 2.510e-04  1.082e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0968947029283247
#        x: [ 1.708e-01  6.319e-02 ...  1.708e-01  6.319e-02]
#      nit: 1
#      jac: [ 3.868e-04  1.517e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09703305022861208
#        x: [ 1.708e-01  6.319e-02 ...  1.708e-01  6.319e-02]
#      nit: 1
#      jac: [ 5.239e-04  1.909e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09722305898464456
#        x: [ 1.708e-01  6.319e-02 ...  1.708e-01  6.319e-02]
#      nit: 1
#      jac: [ 6.622e-04  2.257e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09746453916004949
#        x: [ 1.708e-01  6.319e-02 ...  1.708e-01  6.319e-02]
#      nit: 1
#      jac: [ 8.014e-04  2.562e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09716593010084629
#        x: [-6.118e-01 -1.753e-01 ...  1.708e-01  6.319e-02]
#      nit: 8
#      jac: [ 6.208e-05  1.371e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09698507167529713
#        x: [-6.118e-01 -1.753e-01 ... -6.118e-01 -1.753e-01]
#      nit: 1
#      jac: [-4.472e-04 -1.517e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09678939091993222
#        x: [ 1.728e-01  6.560e-02 ... -6.118e-01 -1.753e-01]
#      nit: 8
#      jac: [-1.936e-05 -3.085e-06 ...  0.000e+00  0.000e+00]
#     nfev: 137
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09677436002030704
#        x: [ 1.728e-01  6.560e-02 ...  1.728e-01  6.560e-02]
#      nit: 1
#      jac: [ 1.228e-04  6.337e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.096811893942788
#        x: [ 1.728e-01  6.560e-02 ...  1.728e-01  6.560e-02]
#      nit: 1
#      jac: [ 2.588e-04  1.128e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09690283333299399
#        x: [ 1.728e-01  6.560e-02 ...  1.728e-01  6.560e-02]
#      nit: 1
#      jac: [ 3.962e-04  1.579e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09704708720270849
#        x: [ 1.728e-01  6.560e-02 ...  1.728e-01  6.560e-02]
#      nit: 1
#      jac: [ 5.350e-04  1.987e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09724451122061484
#        x: [ 1.728e-01  6.560e-02 ...  1.728e-01  6.560e-02]
#      nit: 1
#      jac: [ 6.749e-04  2.351e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0974949078567009
#        x: [ 1.728e-01  6.560e-02 ...  1.728e-01  6.560e-02]
#      nit: 1
#      jac: [ 8.160e-04  2.671e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09718337872603011
#        x: [-6.236e-01 -1.833e-01 ...  1.728e-01  6.560e-02]
#      nit: 8
#      jac: [ 6.323e-05  1.438e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09699501300870428
#        x: [-6.236e-01 -1.833e-01 ... -6.236e-01 -1.833e-01]
#      nit: 1
#      jac: [-4.558e-04 -1.581e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09679114350401363
#        x: [ 1.721e-01  6.709e-02 ... -6.236e-01 -1.833e-01]
#      nit: 8
#      jac: [-2.073e-05 -3.502e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0967740433527775
#        x: [ 1.721e-01  6.709e-02 ...  1.721e-01  6.709e-02]
#      nit: 1
#      jac: [ 1.173e-04  6.342e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09680973831275308
#        x: [ 1.721e-01  6.709e-02 ...  1.721e-01  6.709e-02]
#      nit: 1
#      jac: [ 2.528e-04  1.142e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09689882109845693
#        x: [ 1.721e-01  6.709e-02 ...  1.721e-01  6.709e-02]
#      nit: 1
#      jac: [ 3.897e-04  1.607e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09704120257995297
#        x: [ 1.721e-01  6.709e-02 ...  1.721e-01  6.709e-02]
#      nit: 1
#      jac: [ 5.281e-04  2.028e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09723674030039642
#        x: [ 1.721e-01  6.709e-02 ...  1.721e-01  6.709e-02]
#      nit: 1
#      jac: [ 6.677e-04  2.405e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09748523861856762
#        x: [ 1.721e-01  6.709e-02 ...  1.721e-01  6.709e-02]
#      nit: 1
#      jac: [ 8.084e-04  2.739e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09717789665369603
#        x: [-6.176e-01 -1.886e-01 ...  1.721e-01  6.709e-02]
#      nit: 8
#      jac: [ 6.267e-05  1.498e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09699192996114592
#        x: [-6.176e-01 -1.886e-01 ... -6.176e-01 -1.886e-01]
#      nit: 1
#      jac: [-4.512e-04 -1.618e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09679067600253077
#        x: [ 1.703e-01  6.843e-02 ... -6.176e-01 -1.886e-01]
#      nit: 8
#      jac: [-2.053e-05 -3.695e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09677378835244754
#        x: [ 1.703e-01  6.843e-02 ...  1.703e-01  6.843e-02]
#      nit: 1
#      jac: [ 1.159e-04  6.421e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09680900709251072
#        x: [ 1.703e-01  6.843e-02 ...  1.703e-01  6.843e-02]
#      nit: 1
#      jac: [ 2.499e-04  1.161e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09689691374004017
#        x: [ 1.703e-01  6.843e-02 ...  1.703e-01  6.843e-02]
#      nit: 1
#      jac: [ 3.854e-04  1.636e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09703742035759122
#        x: [ 1.703e-01  6.843e-02 ...  1.703e-01  6.843e-02]
#      nit: 1
#      jac: [ 5.224e-04  2.069e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09723038638932446
#        x: [ 1.703e-01  6.843e-02 ...  1.703e-01  6.843e-02]
#      nit: 1
#      jac: [ 6.607e-04  2.459e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09747561880160704
#        x: [ 1.703e-01  6.843e-02 ...  1.703e-01  6.843e-02]
#      nit: 1
#      jac: [ 8.002e-04  2.805e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09717233504703149
#        x: [-6.115e-01 -1.938e-01 ...  1.703e-01  6.843e-02]
#      nit: 8
#      jac: [ 6.212e-05  1.554e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09698871558472821
#        x: [-6.115e-01 -1.938e-01 ... -6.115e-01 -1.938e-01]
#      nit: 1
#      jac: [-4.463e-04 -1.654e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09679016261462903
#        x: [ 1.683e-01  6.969e-02 ... -6.115e-01 -1.938e-01]
#      nit: 8
#      jac: [-2.034e-05 -3.874e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09677349970307025
#        x: [ 1.683e-01  6.969e-02 ...  1.683e-01  6.969e-02]
#      nit: 1
#      jac: [ 1.142e-04  6.495e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09680816908134204
#        x: [ 1.683e-01  6.969e-02 ...  1.683e-01  6.969e-02]
#      nit: 1
#      jac: [ 2.467e-04  1.178e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09689473991200237
#        x: [ 1.683e-01  6.969e-02 ...  1.683e-01  6.969e-02]
#      nit: 1
#      jac: [ 3.808e-04  1.664e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0970331256113044
#        x: [ 1.683e-01  6.969e-02 ...  1.683e-01  6.969e-02]
#      nit: 1
#      jac: [ 5.163e-04  2.108e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09722318777290373
#        x: [ 1.683e-01  6.969e-02 ...  1.683e-01  6.969e-02]
#      nit: 1
#      jac: [ 6.531e-04  2.509e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ...
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09703594411782035
#        x: [ 6.367e-02  1.716e-01 ...  6.367e-02  1.716e-01]
#      nit: 1
#      jac: [ 1.975e-04  5.245e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09722789970878787
#        x: [ 6.367e-02  1.716e-01 ...  6.367e-02  1.716e-01]
#      nit: 1
#      jac: [ 2.615e-04  6.527e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0974718475443932
#        x: [ 6.367e-02  1.716e-01 ...  6.367e-02  1.716e-01]
#      nit: 1
#      jac: [ 3.295e-04  7.789e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09717015497512294
#        x: [-2.670e-01 -5.814e-01 ...  6.367e-02  1.716e-01]
#      nit: 8
#      jac: [ 3.017e-05  5.628e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09698747853546452
#        x: [-2.670e-01 -5.814e-01 ... -2.670e-01 -5.814e-01]
#      nit: 1
#      jac: [-1.771e-04 -4.404e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09678976729952105
#        x: [ 6.311e-02  1.747e-01 ... -2.670e-01 -5.814e-01]
#      nit: 8
#      jac: [-1.036e-05 -1.679e-05 ...  0.000e+00  0.000e+00]
#     nfev: 137
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09677455518681155
#        x: [ 6.311e-02  1.747e-01 ...  6.311e-02  1.747e-01]
#      nit: 1
#      jac: [ 3.204e-05  1.351e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09681244157567148
#        x: [ 6.311e-02  1.747e-01 ...  6.311e-02  1.747e-01]
#      nit: 1
#      jac: [ 8.340e-05  2.711e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09690427319833494
#        x: [ 6.311e-02  1.747e-01 ...  6.311e-02  1.747e-01]
#      nit: 1
#      jac: [ 1.390e-04  4.054e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09704995816120321
#        x: [ 6.311e-02  1.747e-01 ...  6.311e-02  1.747e-01]
#      nit: 1
#      jac: [ 1.988e-04  5.379e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09724935068099305
#        x: [ 6.311e-02  1.747e-01 ...  6.311e-02  1.747e-01]
#      nit: 1
#      jac: [ 2.626e-04  6.685e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09750225123061806
#        x: [ 6.311e-02  1.747e-01 ...  6.311e-02  1.747e-01]
#      nit: 1
#      jac: [ 3.306e-04  7.970e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09718762526340496
#        x: [-2.685e-01 -5.955e-01 ...  6.311e-02  1.747e-01]
#      nit: 8
#      jac: [ 3.046e-05  5.770e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09699739661022444
#        x: [-2.685e-01 -5.955e-01 ... -2.685e-01 -5.955e-01]
#      nit: 1
#      jac: [-1.778e-04 -4.510e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0967915029058124
#        x: [ 6.159e-02  1.752e-01 ... -2.685e-01 -5.955e-01]
#      nit: 8
#      jac: [-1.088e-05 -1.802e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09677426366473996
#        x: [ 6.159e-02  1.752e-01 ...  6.159e-02  1.752e-01]
#      nit: 1
#      jac: [ 2.852e-05  1.312e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09681039422737614
#        x: [ 6.159e-02  1.752e-01 ...  6.159e-02  1.752e-01]
#      nit: 1
#      jac: [ 7.854e-05  2.677e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09690049727187211
#        x: [ 6.159e-02  1.752e-01 ...  6.159e-02  1.752e-01]
#      nit: 1
#      jac: [ 1.329e-04  4.026e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09704448263401466
#        x: [ 6.159e-02  1.752e-01 ...  6.159e-02  1.752e-01]
#      nit: 1
#      jac: [ 1.913e-04  5.357e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09724220623069724
#        x: [ 6.159e-02  1.752e-01 ...  6.159e-02  1.752e-01]
#      nit: 1
#      jac: [ 2.540e-04  6.670e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09749347020409704
#        x: [ 6.159e-02  1.752e-01 ...  6.159e-02  1.752e-01]
#      nit: 1
#      jac: [ 3.207e-04  7.962e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0971826539928351
#        x: [-2.608e-01 -5.948e-01 ...  6.159e-02  1.752e-01]
#      nit: 8
#      jac: [ 2.965e-05  5.765e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0969946156402608
#        x: [-2.608e-01 -5.948e-01 ... -2.608e-01 -5.948e-01]
#      nit: 1
#      jac: [-1.722e-04 -4.502e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09679108593130237
#        x: [ 5.942e-02  1.748e-01 ... -2.608e-01 -5.948e-01]
#      nit: 8
#      jac: [-1.064e-05 -1.808e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09677402547301561
#        x: [ 5.942e-02  1.748e-01 ...  5.942e-02  1.748e-01]
#      nit: 1
#      jac: [ 2.697e-05  1.306e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09680969906923065
#        x: [ 5.942e-02  1.748e-01 ...  5.942e-02  1.748e-01]
#      nit: 1
#      jac: [ 7.530e-05  2.668e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09689869873821855
#        x: [ 5.942e-02  1.748e-01 ...  5.942e-02  1.748e-01]
#      nit: 1
#      jac: [ 1.278e-04  4.015e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09704093543460579
#        x: [ 5.942e-02  1.748e-01 ...  5.942e-02  1.748e-01]
#      nit: 1
#      jac: [ 1.846e-04  5.344e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09723626684865128
#        x: [ 5.942e-02  1.748e-01 ...  5.942e-02  1.748e-01]
#      nit: 1
#      jac: [ 2.456e-04  6.655e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0974844975486322
#        x: [ 5.942e-02  1.748e-01 ...  5.942e-02  1.748e-01]
#      nit: 1
#      jac: [ 3.106e-04  7.946e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09717746746258249
#        x: [-2.531e-01 -5.938e-01 ...  5.942e-02  1.748e-01]
#      nit: 8
#      jac: [ 2.889e-05  5.764e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09699165294428935
#        x: [-2.531e-01 -5.938e-01 ... -2.531e-01 -5.938e-01]
#      nit: 1
#      jac: [-1.664e-04 -4.492e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09679062365083935
#        x: [ 5.721e-02  1.742e-01 ... -2.531e-01 -5.938e-01]
#      nit: 8
#      jac: [-1.036e-05 -1.805e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09677376188345588
#        x: [ 5.721e-02  1.742e-01 ...  5.721e-02  1.742e-01]
#      nit: 1
#      jac: [ 2.544e-05  1.299e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09680893020903558
#        x: [ 5.721e-02  1.742e-01 ...  5.721e-02  1.742e-01]
#      nit: 1
#      jac: [ 7.197e-05  2.657e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09689670909402603
#        x: [ 5.721e-02  1.742e-01 ...  5.721e-02  1.742e-01]
#      nit: 1
#      jac: [ 1.228e-04  4.000e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0970370107305274
#        x: [ 5.721e-02  1.742e-01 ...  5.721e-02  1.742e-01]
#      nit: 1
#      jac: [ 1.778e-04  5.326e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09722969477052534
#        x: [ 5.721e-02  1.742e-01 ...  5.721e-02  1.742e-01]
#      nit: 1
#      jac: [ 2.370e-04  6.634e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09747456846629055
#        x: [ 5.721e-02  1.742e-01 ...  5.721e-02  1.742e-01]
#      nit: 1
#      jac: [ 3.002e-04  7.923e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09717172796510964
#        x: [-2.451e-01 -5.922e-01 ...  5.721e-02  1.742e-01]
#      nit: 8
#      jac: [ 2.809e-05  5.752e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09698836131491051
#        x: [-2.451e-01 -5.922e-01 ... -2.451e-01 -5.922e-01]
#      nit: 1
#      jac: [-1.606e-04 -4.477e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0967901058616285
#        x: [ 5.493e-02  1.735e-01 ... -2.451e-01 -5.922e-01]
#      nit: 8
#      jac: [-1.013e-05 -1.808e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0967734553825772
#        x: [ 5.493e-02  1.735e-01 ...  5.493e-02  1.735e-01]
#      nit: 1
#      jac: [ 2.377e-05  1.290e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09680802357731699
#        x: [ 5.493e-02  1.735e-01 ...  5.493e-02  1.735e-01]
#      nit: 1
#      jac: [ 6.856e-05  2.643e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09689437749751462
#        x: [ 5.493e-02  1.735e-01 ...  5.493e-02  1.735e-01]
#      nit: 1
#      jac: [ 1.176e-04  3.980e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09703243077892632
#        x: [ 5.493e-02  1.735e-01 ...  5.493e-02  1.735e-01]
#      nit: 1
#      jac: [ 1.708e-04  5.302e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09722204535176338
#        x: [ 5.493e-02  1.735e-01 ...  5.493e-02  1.735e-01]
#      nit: 1
#      jac: [ 2.281e-04  6.605e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09746303157878233
#        x: [ 5.493e-02  1.735e-01 ...  5.493e-02  1.735e-01]
#      nit: 1
#      jac: [ 2.894e-04  7.891e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09716506034579808
#        x: [-2.369e-01 -5.899e-01 ...  5.493e-02  1.735e-01]
#      nit: 8
#      jac: [ 2.728e-05  5.743e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09698452423980553
#        x: [-2.369e-01 -5.899e-01 ... -2.369e-01 -5.899e-01]
#      nit: 1
#      jac: [-1.545e-04 -4.456e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09678929005427683
#        x: [ 5.419e-02  1.764e-01 ... -2.369e-01 -5.899e-01]
#      nit: 8
#      jac: [-9.462e-06 -1.712e-05 ...  0.000e+00  0.000e+00]
#     nfev: 137
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09677430545807608
#        x: [ 5.419e-02  1.764e-01 ...  5.419e-02  1.764e-01]
#      nit: 1
#      jac: [ 2.532e-05  1.357e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09681173412034605
#        x: [ 5.419e-02  1.764e-01 ...  5.419e-02  1.764e-01]
#      nit: 1
#      jac: [ 6.968e-05  2.731e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09690241486949525
#        x: [ 5.419e-02  1.764e-01 ...  5.419e-02  1.764e-01]
#      nit: 1
#      jac: [ 1.184e-04  4.091e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09704625697964553
#        x: [ 5.419e-02  1.764e-01 ...  5.419e-02  1.764e-01]
#      nit: 1
#      jac: [ 1.713e-04  5.435e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09724311653710438
#        x: [ 5.419e-02  1.764e-01 ...  5.419e-02  1.764e-01]
#      nit: 1
#      jac: [ 2.284e-04  6.762e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09749279658434595
#        x: [ 5.419e-02  1.764e-01 ...  5.419e-02  1.764e-01]
#      nit: 1
#      jac: [ 2.896e-04  8.070e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1

# %%
plot_componentes(evolucao_1, evolucao_2, 1)

# Controlabilidade da equação de lindblad, heisenberg
