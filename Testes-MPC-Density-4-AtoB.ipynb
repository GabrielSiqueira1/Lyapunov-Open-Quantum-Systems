# %%
# Bilbiotecas para auxílio na programação matemática
import math, sys 
import numpy as np
import sympy as sp
import cmath
import time

from scipy import sparse # Produção das diagonais das matrizes
from scipy.sparse import diags 
from scipy.linalg import expm

# Plotagem 2D e 3D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm


from os import path # Suficiente para manipulação de arquivos
    
# Para solução exata
from scipy.special import hermite
from math import factorial

# %matplotlib inline
count = 0

# Para otimização dos sistemas
from scipy import optimize
from random import randint, uniform, random

# %%
# Manipulação das matrizes, soma e subtração

def somar(A, B):
    C = []
    num_linhas_a = len(A)
    num_colunas_a = len(A[0])
    
    for i in range (num_linhas_a):
        linha = [0]*num_colunas_a
        C.append(linha)
        for j in range(num_colunas_a):
            C[i][j] = A[i][j] + B[i][j]

    return C

def sub(A, B):
    C = []
    num_linhas_a = len(A)
    num_colunas_a = len(A[0])
    
    for i in range (num_linhas_a):
        linha = [0]*num_colunas_a
        C.append(linha)
        for j in range(num_linhas_a):
            C[i][j] = A[i][j] - B[i][j]

    return C

# %%
## CONSTANTES PARA O CONTROLADOR

# Considerações: constante de Planck verdadeira: 1, massa: 1

TEMPO_ANALISE = 10 
QUANTIDADE_PONTOS_AMOSTRAGEM = 1000
PASSO = TEMPO_ANALISE/QUANTIDADE_PONTOS_AMOSTRAGEM

MIN_HORIZONTE = 3 # Horizonte mínimo da análise
MAX_HORIZONTE = 30 # Horizonte máximo da análise

# Com horizonte em 10, a avaliação dura em torno de 80 minutos 

DESEJADO = [[1.00],[0.00]] # [[c1];[c2]] = [[0.707],[-0.707]]
RHO_DESEJADO = np.matmul(DESEJADO, np.transpose(DESEJADO))

# Determinação dos valores de início e fim da análise
num = PASSO
contador = 0
while num < 1:
    num *= 10
    contador += 1

EXPOENTE = contador
INICIO_ANALISE = 0*10**(-EXPOENTE) # Tempo inicial da analise em um horizonte
FINAL_ANALISE = (1*10**(-EXPOENTE))+PASSO # Tempo final da analise em um horizonte

# %%
## CONSTANTES PARA O ALGORITMO GENÉTICO

ELITISMO = True
PORCENTAGEM_ELITISMO = 0.20

TAMANHO_POP = 50
TAXA_MUTACAO = 0.10
TAXA_CRUZAMENTO = 0.70
GERACOES = 100

# Valores mínimos e máximos para gerar uma população
MIN = -5
MAX = 5

# %%
def dpsi_dt(t, ro, H): # A derivada da ro em relação ao tempo não tem dependência temporal
    A = np.zeros((2,2), dtype=np.complex_)
    A = (np.dot(H,ro))-(np.dot(ro, H)) # [H,p]
    return -1j*A

# Runge-Kutta de quarta ordem

def runge_kutta(onda, fator_runge_kutta, hamiltoniano, tempo_inicial = 0):

    k1 = dpsi_dt(tempo_inicial, onda, hamiltoniano)
    k2 = dpsi_dt(tempo_inicial + 0.5 * fator_runge_kutta, somar(onda, np.dot((0.5*fator_runge_kutta), k1)), hamiltoniano)
    k3 = dpsi_dt(tempo_inicial + 0.5 * fator_runge_kutta, somar(onda, np.dot((0.5*fator_runge_kutta), k2)), hamiltoniano)
    k4 = dpsi_dt(tempo_inicial + fator_runge_kutta, somar(onda, np.dot(fator_runge_kutta, k3)), hamiltoniano)
    
    ## y(i+1) = y(i) + h/6*(k1+2*k2+2*k3+k4)
    
    A = somar(np.dot(2,k3), k4)
    B = somar(np.dot(2,k2), k1)
    C = somar(A, B)

    runge = somar(onda,np.dot((fator_runge_kutta / 6.0),(C)))
    
    return runge

# %%
def func_objetivo(vetor_controles, tempo_atual, rho_desejado, 
                  rho_atual, H, horizonte, fator_runge_kutta):
    
    fo = 0
    pos = 0
    
    tempo_inicial = INICIO_ANALISE
    tempo_final = FINAL_ANALISE
    
    controles = np.zeros((2,2), dtype=np.complex_)
    controles = [[0, complex(vetor_controles[0], vetor_controles[1])], 
                 [complex(vetor_controles[0], -vetor_controles[1]), 0]]
    
    matriz_inicial = rho_atual

    matriz_desejada = np.zeros((2,2),dtype=np.complex_)
    hamiltoniano = H

    H = [[np.exp(-1j*np.pi*tempo_atual/2),0],[0,np.exp(1j*np.pi*tempo_atual/2)]]
    U = H
    U = np.asmatrix(U)
    U_dagger = U.getH()
    teste = np.dot(np.dot(U,rho_desejado),U_dagger)
    matriz_desejada = np.squeeze(np.asarray(teste))

    matriz_teste = sub(matriz_inicial, matriz_desejada)
    
    teste = []
    for m in range(0, 2):
        teste.append(abs(matriz_teste[0][m])+abs(matriz_teste[0][m]))
    
    fo += max(teste)

    runge = runge_kutta(matriz_inicial, fator_runge_kutta, 
                        somar(hamiltoniano, controles), tempo_inicial = tempo_inicial)

    matriz_inicial = runge

    tempo_inicial = round(tempo_inicial+PASSO, EXPOENTE)
    tempo_final = round(tempo_final+PASSO, EXPOENTE)
    tempo = round(tempo_atual+PASSO, EXPOENTE)
    pos += 2

    while horizonte > 1:
        
        H = [[np.exp(-1j*np.pi*tempo/2),0],[0,np.exp(1j*np.pi*tempo/2)]]
        U = H
        U = np.asmatrix(U)
        U_dagger = U.getH()
        teste = np.dot(np.dot(U,rho_desejado),U_dagger)
        matriz_desejada = np.squeeze(np.asarray(teste))
        
        teste = []
        for m in range(0, 2):
            teste.append(abs(matriz_teste[0][m])+abs(matriz_teste[0][m]))

        matriz_teste = sub(matriz_inicial, matriz_desejada)
        
        fo += max(teste)
        
        controles = [[0, complex(vetor_controles[pos], vetor_controles[pos+1])], 
                     [complex(vetor_controles[pos], -vetor_controles[pos+1]), 0]]

        runge = runge_kutta(matriz_inicial, fator_runge_kutta, 
                        somar(hamiltoniano, controles), tempo_inicial = tempo_inicial)

        matriz_inicial = runge

        tempo_inicial = round(tempo_inicial+PASSO, EXPOENTE)
        tempo_final = round(tempo_final+PASSO, EXPOENTE)
        tempo = round(tempo_atual+PASSO, EXPOENTE)
        horizonte -= 1

    return fo

# %%
def main(horizonte, rho_inicial):
    
    u = [] # Controles 
    for i in range(0, 2*horizonte):
        u.append(uniform(-5,5))

    evolucao_1 = np.zeros((2,QUANTIDADE_PONTOS_AMOSTRAGEM), dtype=np.complex_)
    evolucao_2 = np.zeros((2,QUANTIDADE_PONTOS_AMOSTRAGEM), dtype=np.complex_)
        
    # O que será retornado por essa função
    
    vetor_controles = np.zeros((1, QUANTIDADE_PONTOS_AMOSTRAGEM), dtype=np.complex_) # Valores de controle
    constantes = np.zeros((2, QUANTIDADE_PONTOS_AMOSTRAGEM), dtype=np.complex_) # Para verificar se as integrais estão resultando em 1
    valores_onda = np.zeros((2, QUANTIDADE_PONTOS_AMOSTRAGEM), dtype=np.complex_)
    
    H = np.zeros((2,2), dtype=np.complex_)
    H = [[(3/2*np.pi), 0], [0, (1/2*np.pi)]]
    
    tempo = 0
    pos = 0
    while tempo < TEMPO_ANALISE:

        evolucao_1[0][pos] = rho_inicial[0][0]
        evolucao_1[1][pos] = rho_inicial[1][1]
    
        resultado = optimize.minimize(func_objetivo, u, args=(tempo, RHO_DESEJADO, rho_inicial, H, horizonte, PASSO), method='SLSQP')

        print('------------------')
        print(resultado)
        
        controle = np.zeros((2,2), dtype=np.complex_)
        controle = [[0, complex(resultado.x[0], resultado.x[1])],[complex(resultado.x[0], -resultado.x[1]), 0]]
        H = somar(H, controle)
    
        ## Adaptação da onda ao controle
        
        rho_avancado = runge_kutta(rho_inicial, PASSO, H, tempo_inicial = INICIO_ANALISE)
        rho_inicial = rho_avancado
        
        # Reset
        H = [[(3/2*np.pi), 0], [0, (1/2*np.pi)]]
    
        u = [] # Controles 
        for i in range(0, 2*horizonte):
            u.append(resultado.x[0])
            u.append(resultado.x[1])
        
        pos += 1
        tempo = round(tempo+PASSO, EXPOENTE)

    return evolucao_1

# %%
# Plotagem 2D e 3D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm

def plot_componentes(valores_onda, componente):
    
    ts1 = np.linspace(0, TEMPO_ANALISE, QUANTIDADE_PONTOS_AMOSTRAGEM)
    
    real_primeiro = [elemento.real for elemento in valores_onda[componente-1]]
    
    # Plotagem

    plt.ylabel('Pesos') 
    plt.xlabel('Tempo') 
    plt.title(f"{componente}ª componente -> real")
    plt.plot(ts1, real_primeiro, color='r', marker='*', linewidth=1, markersize=1, label="primeiro")
    plt.legend(loc='upper right')
    

    plt.axis([0,TEMPO_ANALISE,0,1])
    plt.tight_layout()

# %%
PSI = np.ones((2,1), dtype=np.complex_)
PSI = [[0.80],[0.60]]
ro = np.matmul(PSI, np.transpose(PSI))
evolucao_1 = main(4, ro)
# Out:
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 1.9690925098572198
#        x: [ 1.614e+00  6.382e+01 -1.245e+00  6.605e-01  2.991e+00
#             2.037e+00  4.511e+00 -6.018e-01]
#      nit: 47
#      jac: [ 3.861e-03 -1.622e-02 -3.637e-04 -2.227e-04  0.000e+00
#             0.000e+00  0.000e+00  0.000e+00]
#     nfev: 450
#     njev: 47
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.1131169608176056
#        x: [-6.178e-01 -4.411e-03 ...  1.614e+00  6.382e+01]
#      nit: 39
#      jac: [-6.537e-03  1.793e-02 ...  0.000e+00  0.000e+00]
#     nfev: 693
#     njev: 39
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09774411240106207
#        x: [ 3.674e-01  9.850e-01 ... -6.178e-01 -4.411e-03]
#      nit: 8
#      jac: [-2.056e-06 -1.968e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09713122994448509
#        x: [ 7.616e-03  1.222e-01 ...  3.674e-01  9.850e-01]
#      nit: 8
#      jac: [ 1.712e-05 -2.550e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09711667367210253
#        x: [ 7.616e-03  1.222e-01 ...  7.616e-03  1.222e-01]
#      nit: 1
#      jac: [ 2.746e-05  5.874e-05 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09761564335992423
#        x: [-5.558e-01 -4.357e-01 ...  1.109e-01  1.024e-01]
#      nit: 8
#      jac: [ 5.765e-05  4.074e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09739094410041615
#        x: [-5.558e-01 -4.357e-01 ... -5.558e-01 -4.357e-01]
#      nit: 1
#      jac: [-3.963e-04 -3.408e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09715017513300617
#        x: [ 1.472e-01  1.360e-01 ... -5.558e-01 -4.357e-01]
#      nit: 8
#      jac: [-1.942e-05 -1.141e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09713056150150723
#        x: [ 1.472e-01  1.360e-01 ...  1.472e-01  1.360e-01]
#      nit: 1
#      jac: [ 9.406e-05  1.114e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09717300711416321
#        x: [ 1.472e-01  1.360e-01 ...  1.472e-01  1.360e-01]
#      nit: 1
#      jac: [ 2.107e-04  2.163e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09727827199479755
#        x: [ 1.472e-01  1.360e-01 ...  1.472e-01  1.360e-01]
#      nit: 1
#      jac: [ 3.306e-04  3.175e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09744625056884026
#        x: [ 1.472e-01  1.360e-01 ...  1.472e-01  1.360e-01]
#      nit: 1
#      jac: [ 4.536e-04  4.149e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09767677436352362
#        x: [ 1.472e-01  1.360e-01 ...  1.472e-01  1.360e-01]
#      nit: 1
#      jac: [ 5.796e-04  5.083e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09742431804619645
#        x: [-5.460e-01 -4.489e-01 ...  1.472e-01  1.360e-01]
#      nit: 8
#      jac: [ 1.964e-05  1.505e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09747117028541852
#        x: [-5.460e-01 -4.489e-01 ... -5.460e-01 -4.489e-01]
#      nit: 1
#      jac: [-5.192e-04 -4.492e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09722528905343641
#        x: [ 2.496e-01  2.160e-01 ... -5.460e-01 -4.489e-01]
#      nit: 8
#      jac: [-3.240e-05 -1.949e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09716889214205993
#        x: [ 2.496e-01  2.160e-01 ...  2.496e-01  2.160e-01]
#      nit: 1
#      jac: [ 1.617e-04  1.710e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09728120829766329
#        x: [ 2.496e-01  2.160e-01 ...  2.496e-01  2.160e-01]
#      nit: 1
#      jac: [ 3.591e-04  3.374e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09756383297203453
#        x: [ 2.496e-01  2.160e-01 ...  2.496e-01  2.160e-01]
#      nit: 1
#      jac: [ 5.616e-04  4.976e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09737443450441563
#        x: [-3.967e-01 -3.351e-01 ...  2.496e-01  2.160e-01]
#      nit: 8
#      jac: [ 4.084e-05  2.979e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09726266738318268
#        x: [-3.967e-01 -3.351e-01 ... -3.967e-01 -3.351e-01]
#      nit: 1
#      jac: [-2.861e-04 -2.687e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.097539575169596
#        x: [-3.818e-01 -3.220e-01 ... -3.967e-01 -3.351e-01]
#      nit: 2
#      jac: [-5.825e-04 -5.106e-04 ...  0.000e+00  0.000e+00]
#     nfev: 34
#     njev: 2
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09734265911268802
#        x: [ 3.508e-01  2.975e-01 ... -3.818e-01 -3.220e-01]
#      nit: 8
#      jac: [-4.445e-05 -3.058e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09722483987973751
#        x: [ 3.508e-01  2.975e-01 ...  3.508e-01  2.975e-01]
#      nit: 1
#      jac: [ 2.273e-04  2.241e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09743541753236284
#        x: [ 3.508e-01  2.975e-01 ...  3.508e-01  2.975e-01]
#      nit: 1
#      jac: [ 5.043e-04  4.532e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09728104231976609
#        x: [-3.010e-01 -2.634e-01 ...  3.508e-01  2.975e-01]
#      nit: 8
#      jac: [ 3.660e-05  2.643e-05 ...  0.000e+00  0.000e+00]
#     nfev: 137
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09719692025441629
#        x: [-3.010e-01 -2.634e-01 ... -3.010e-01 -2.634e-01]
#      nit: 1
#      jac: [-1.991e-04 -2.012e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09736060596295792
#        x: [-3.010e-01 -2.634e-01 ... -3.010e-01 -2.634e-01]
#      nit: 1
#      jac: [-4.370e-04 -4.041e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09724037220996684
#        x: [ 2.764e-01  2.478e-01 ... -3.010e-01 -2.634e-01]
#      nit: 8
#      jac: [-2.822e-05 -2.091e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09718789758177615
#        x: [ 2.764e-01  2.478e-01 ...  2.764e-01  2.478e-01]
#      nit: 1
#      jac: [ 2.014e-04  2.033e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09734636661789908
#        x: [ 2.764e-01  2.478e-01 ...  2.764e-01  2.478e-01]
#      nit: 1
#      jac: [ 4.203e-04  3.936e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09769333112375511
#        x: [ 2.617e-01  2.345e-01 ...  2.764e-01  2.478e-01]
#      nit: 2
#      jac: [ 6.279e-04  5.615e-04 ...  0.000e+00  0.000e+00]
#     nfev: 34
#     njev: 2
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09745600298643042
#        x: [-4.240e-01 -3.607e-01 ...  2.617e-01  2.345e-01]
#      nit: 8
#      jac: [ 5.342e-05  3.853e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.097278472385802
#        x: [-4.240e-01 -3.607e-01 ... -4.240e-01 -3.607e-01]
#      nit: 1
#      jac: [-2.744e-04 -2.660e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09712607174180476
#        x: [ 1.035e-01  1.115e-01 ... -4.240e-01 -3.607e-01]
#      nit: 8
#      jac: [-8.926e-06 -6.601e-06 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09712257783045875
#        x: [ 1.035e-01  1.115e-01 ...  1.035e-01  1.115e-01]
#      nit: 1
#      jac: [ 8.258e-05  1.035e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09715375552203565
#        x: [ 1.035e-01  1.115e-01 ...  1.035e-01  1.115e-01]
#      nit: 1
#      jac: [ 1.652e-04  1.891e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09722109050754524
#        x: [ 1.035e-01  1.115e-01 ...  1.035e-01  1.115e-01]
#      nit: 1
#      jac: [ 2.505e-04  2.720e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0973245157121907
#        x: [ 1.035e-01  1.115e-01 ...  1.035e-01  1.115e-01]
#      nit: 1
#      jac: [ 3.383e-04  3.523e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09746392811041549
#        x: [ 1.035e-01  1.115e-01 ...  1.035e-01  1.115e-01]
#      nit: 1
#      jac: [ 4.286e-04  4.298e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09763918882852574
#        x: [ 1.035e-01  1.115e-01 ...  1.035e-01  1.115e-01]
#      nit: 1
#      jac: [ 5.213e-04  5.043e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09785012328302933
#        x: [ 1.035e-01  1.115e-01 ...  1.035e-01  1.115e-01]
#      nit: 1
#      jac: [ 6.163e-04  5.759e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09752931514919472
#        x: [-5.106e-01 -4.475e-01 ...  1.035e-01  1.115e-01]
#      nit: 8
#      jac: [ 4.400e-05  3.414e-05 ...  0.000e+00  0.000e+00]
#     nfev: 137
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09738168574549855
#        x: [-5.106e-01 -4.475e-01 ... -5.106e-01 -4.475e-01]
#      nit: 1
#      jac: [-3.920e-04 -3.727e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.
-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0978356536188072
#        x: [ 1.230e-01  1.374e-01 ...  1.230e-01  1.374e-01]
#      nit: 1
#      jac: [ 5.961e-04  6.087e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09752940853069436
#        x: [-4.648e-01 -4.467e-01 ...  1.230e-01  1.374e-01]
#      nit: 8
#      jac: [ 4.907e-05  4.168e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09734405900377463
#        x: [-4.648e-01 -4.467e-01 ... -4.648e-01 -4.467e-01]
#      nit: 1
#      jac: [-3.286e-04 -3.476e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09714354521105917
#        x: [ 1.207e-01  1.377e-01 ... -4.648e-01 -4.467e-01]
#      nit: 8
#      jac: [-1.660e-05 -1.252e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09712672307549108
#        x: [ 1.207e-01  1.377e-01 ...  1.207e-01  1.377e-01]
#      nit: 1
#      jac: [ 7.412e-05  1.094e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09716178697582034
#        x: [ 1.207e-01  1.377e-01 ...  1.207e-01  1.377e-01]
#      nit: 1
#      jac: [ 1.700e-04  2.160e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09724931503827006
#        x: [ 1.207e-01  1.377e-01 ...  1.207e-01  1.377e-01]
#      nit: 1
#      jac: [ 2.692e-04  3.195e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09738921970901693
#        x: [ 1.207e-01  1.377e-01 ...  1.207e-01  1.377e-01]
#      nit: 1
#      jac: [ 3.716e-04  4.198e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09758136104221427
#        x: [ 1.207e-01  1.377e-01 ...  1.207e-01  1.377e-01]
#      nit: 1
#      jac: [ 4.771e-04  5.169e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09782554683997957
#        x: [ 1.207e-01  1.377e-01 ...  1.207e-01  1.377e-01]
#      nit: 1
#      jac: [ 5.856e-04  6.106e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09752356591844547
#        x: [-4.569e-01 -4.484e-01 ...  1.207e-01  1.377e-01]
#      nit: 8
#      jac: [ 4.826e-05  4.181e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09734075522862495
#        x: [-4.569e-01 -4.484e-01 ... -4.569e-01 -4.484e-01]
#      nit: 1
#      jac: [-3.227e-04 -3.486e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09714283236982024
#        x: [ 1.213e-01  1.408e-01 ... -4.569e-01 -4.484e-01]
#      nit: 8
#      jac: [-1.571e-05 -1.207e-05 ...  0.000e+00  0.000e+00]
#     nfev: 137
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09712759615253463
#        x: [ 1.213e-01  1.408e-01 ...  1.213e-01  1.408e-01]
#      nit: 1
#      jac: [ 7.813e-05  1.149e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0971655279307857
#        x: [ 1.213e-01  1.408e-01 ...  1.213e-01  1.408e-01]
#      nit: 1
#      jac: [ 1.746e-04  2.237e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09725747746628222
#        x: [ 1.213e-01  1.408e-01 ...  1.213e-01  1.408e-01]
#      nit: 1
#      jac: [ 2.745e-04  3.295e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09740335274561396
#        x: [ 1.213e-01  1.408e-01 ...  1.213e-01  1.408e-01]
#      nit: 1
#      jac: [ 3.776e-04  4.321e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09760300779216435
#        x: [ 1.213e-01  1.408e-01 ...  1.213e-01  1.408e-01]
#      nit: 1
#      jac: [ 4.839e-04  5.314e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09785624281219207
#        x: [ 1.213e-01  1.408e-01 ...  1.213e-01  1.408e-01]
#      nit: 1
#      jac: [ 5.933e-04  6.273e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09754120541470557
#        x: [-4.634e-01 -4.611e-01 ...  1.213e-01  1.408e-01]
#      nit: 8
#      jac: [ 4.901e-05  4.305e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09735078721630419
#        x: [-4.634e-01 -4.611e-01 ... -4.634e-01 -4.611e-01]
#      nit: 1
#      jac: [-3.272e-04 -3.583e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09714459336736891
#        x: [ 1.201e-01  1.419e-01 ... -4.634e-01 -4.611e-01]
#      nit: 8
#      jac: [-1.661e-05 -1.301e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09712731354852644
#        x: [ 1.201e-01  1.419e-01 ...  1.201e-01  1.419e-01]
#      nit: 1
#      jac: [ 7.343e-05  1.124e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09716350164770526
#        x: [ 1.201e-01  1.419e-01 ...  1.201e-01  1.419e-01]
#      nit: 1
#      jac: [ 1.689e-04  2.223e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09725376160993782
#        x: [ 1.201e-01  1.419e-01 ...  1.201e-01  1.419e-01]
#      nit: 1
#      jac: [ 2.678e-04  3.291e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09739800311158087
#        x: [ 1.201e-01  1.419e-01 ...  1.201e-01  1.419e-01]
#      nit: 1
#      jac: [ 3.700e-04  4.328e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09759608180936996
#        x: [ 1.201e-01  1.419e-01 ...  1.201e-01  1.419e-01]
#      nit: 1
#      jac: [ 4.754e-04  5.331e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09784779948486055
#        x: [ 1.201e-01  1.419e-01 ...  1.201e-01  1.419e-01]
#      nit: 1
#      jac: [ 5.838e-04  6.301e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09753642956598063
#        x: [-4.561e-01 -4.633e-01 ...  1.201e-01  1.419e-01]
#      nit: 8
#      jac: [ 4.826e-05  4.330e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09734810253927706
#        x: [-4.561e-01 -4.633e-01 ... -4.561e-01 -4.633e-01]
#      nit: 1
#      jac: [-3.217e-04 -3.597e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0971441865870919
#        x: [ 1.179e-01  1.423e-01 ... -4.561e-01 -4.633e-01]
#      nit: 8
#      jac: [-1.642e-05 -1.313e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09712707548210875
#        x: [ 1.179e-01  1.423e-01 ...  1.179e-01  1.423e-01]
#      nit: 1
#      jac: [ 7.179e-05  1.125e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09716280052623127
#        x: [ 1.179e-01  1.423e-01 ...  1.179e-01  1.423e-01]
#      nit: 1
#      jac: [ 1.656e-04  2.227e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09725195496275507
#        x: [ 1.179e-01  1.423e-01 ...  1.179e-01  1.423e-01]
#      nit: 1
#      jac: [ 2.627e-04  3.298e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09739444958899557
#        x: [ 1.179e-01  1.423e-01 ...  1.179e-01  1.423e-01]
#      nit: 1
#      jac: [ 3.632e-04  4.339e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09759014183321235
#        x: [ 1.179e-01  1.423e-01 ...  1.179e-01  1.423e-01]
#      nit: 1
#      jac: [ 4.670e-04  5.348e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0978388358972595
#        x: [ 1.179e-01  1.423e-01 ...  1.179e-01  1.423e-01]
#      nit: 1
#      jac: [ 5.738e-04  6.323e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09753124886846254
#        x: [-4.485e-01 -4.651e-01 ...  1.179e-01  1.423e-01]
#      nit: 8
#      jac: [ 4.750e-05  4.356e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09734513728388783
#        x: [-4.485e-01 -4.651e-01 ... -4.485e-01 -4.651e-01]
#      nit: 1
#      jac: [-3.159e-04 -3.607e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09714372204492672
#        x: [ 1.157e-01  1.426e-01 ... -4.485e-01 -4.651e-01]
#      nit: 8
#      jac: [-1.615e-05 -1.319e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09712681942540624
#        x: [ 1.157e-01  1.426e-01 ...  1.157e-01  1.426e-01]
#      nit: 1
#      jac: [ 7.011e-05  1.124e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09716206322125842
#        x: [ 1.157e-01  1.426e-01 ...  1.157e-01  1.426e-01]
#      nit: 1
#      jac: [ 1.621e-04  2.229e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09725003558767509
#        x: [ 1.157e-01  1.426e-01 ...  1.157e-01  1.426e-01]
#      nit: 1
#      jac: [ 2.576e-04  3.303e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09739064852044876
#        x: [ 1.157e-01  1.426e-01 ...  1.157e-01  1.426e-01]
#      nit: 1
#      jac: [ 3.563e-04  4.347e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0975837613557533
#        x: [ 1.157e-01  1.426e-01 ...  1.157e-01  1.426e-01]
#      nit: 1
#      jac: [ 4.583e-04  5.360e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09782918091085913
#        x: [ 1.157e-01  1.426e-01 ...  1.157e-01  1.426e-01]
#      nit: 1
#      jac: [ 5.634e-04  6.340e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ...
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09758044091047946
#        x: [-2.609e-02  1.811e-01 ... -2.609e-02  1.811e-01]
#      nit: 1
#      jac: [-8.222e-05  6.979e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09782415544617895
#        x: [-2.609e-02  1.811e-01 ... -2.609e-02  1.811e-01]
#      nit: 1
#      jac: [-8.284e-05  8.411e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09752276245098979
#        x: [ 4.335e-02 -6.380e-01 ... -2.609e-02  1.811e-01]
#      nit: 8
#      jac: [-4.023e-07  6.385e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09734024551526277
#        x: [ 4.335e-02 -6.380e-01 ...  4.335e-02 -6.380e-01]
#      nit: 1
#      jac: [ 5.485e-05 -4.712e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09714273746020119
#        x: [-2.804e-02  1.835e-01 ...  4.335e-02 -6.380e-01]
#      nit: 8
#      jac: [-1.043e-06 -1.968e-05 ...  0.000e+00  0.000e+00]
#     nfev: 137
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09712756272852818
#        x: [-2.804e-02  1.835e-01 ... -2.804e-02  1.835e-01]
#      nit: 1
#      jac: [-3.640e-05  1.340e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09716544699252694
#        x: [-2.804e-02  1.835e-01 ... -2.804e-02  1.835e-01]
#      nit: 1
#      jac: [-5.633e-05  2.780e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09725723966658784
#        x: [-2.804e-02  1.835e-01 ... -2.804e-02  1.835e-01]
#      nit: 1
#      jac: [-7.169e-05  4.224e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09740284889683393
#        x: [-2.804e-02  1.835e-01 ... -2.804e-02  1.835e-01]
#      nit: 1
#      jac: [-8.251e-05  5.674e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09760212897694931
#        x: [-2.804e-02  1.835e-01 ... -2.804e-02  1.835e-01]
#      nit: 1
#      jac: [-8.877e-05  7.125e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09785488049398405
#        x: [-2.804e-02  1.835e-01 ... -2.804e-02  1.835e-01]
#      nit: 1
#      jac: [-9.046e-05  8.578e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09754041675822389
#        x: [ 4.873e-02 -6.513e-01 ... -2.804e-02  1.835e-01]
#      nit: 8
#      jac: [-8.345e-07  6.516e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09735033126967729
#        x: [ 4.873e-02 -6.513e-01 ...  4.873e-02 -6.513e-01]
#      nit: 1
#      jac: [ 5.932e-05 -4.811e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0971445215001987
#        x: [-2.965e-02  1.834e-01 ...  4.873e-02 -6.513e-01]
#      nit: 8
#      jac: [-9.388e-07 -2.106e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09712728231532353
#        x: [-2.965e-02  1.834e-01 ... -2.965e-02  1.834e-01]
#      nit: 1
#      jac: [-3.763e-05  1.288e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09716341799943096
#        x: [-2.965e-02  1.834e-01 ... -2.965e-02  1.834e-01]
#      nit: 1
#      jac: [-5.893e-05  2.727e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.
-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0975249987420308
#        x: [ 6.775e-02 -6.376e-01 ... -3.304e-02  1.805e-01]
#      nit: 8
#      jac: [-2.846e-06  6.396e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.097341548108141
#        x: [ 6.775e-02 -6.376e-01 ...  6.775e-02 -6.376e-01]
#      nit: 1
#      jac: [ 7.293e-05 -4.702e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09714294969089465
#        x: [-3.509e-02  1.829e-01 ...  6.775e-02 -6.376e-01]
#      nit: 8
#      jac: [-2.980e-07 -1.977e-05 ...  0.000e+00  0.000e+00]
#     nfev: 137
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0971276735688853
#        x: [-3.509e-02  1.829e-01 ... -3.509e-02  1.829e-01]
#      nit: 1
#      jac: [-4.156e-05  1.329e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09716576049145509
#        x: [-3.509e-02  1.829e-01 ... -3.509e-02  1.829e-01]
#      nit: 1
#      jac: [-6.701e-05  2.764e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09725806337664733
#        x: [-3.509e-02  1.829e-01 ... -3.509e-02  1.829e-01]
#      nit: 1
#      jac: [-8.790e-05  4.206e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09740448985277506
#        x: [-3.509e-02  1.829e-01 ... -3.509e-02  1.829e-01]
#      nit: 1
#      jac: [-1.043e-04  5.654e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09760489338421752
#        x: [-3.509e-02  1.829e-01 ... -3.509e-02  1.829e-01]
#      nit: 1
#      jac: [-1.161e-04  7.106e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09785907341806332
#        x: [-3.509e-02  1.829e-01 ... -3.509e-02  1.829e-01]
#      nit: 1
#      jac: [-1.233e-04  8.562e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09754284091642296
#        x: [ 7.364e-02 -6.508e-01 ... -3.509e-02  1.829e-01]
#      nit: 8
#      jac: [-3.293e-06  6.530e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09735169044581715
#        x: [ 7.364e-02 -6.508e-01 ...  7.364e-02 -6.508e-01]
#      nit: 1
#      jac: [ 7.777e-05 -4.798e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09714472542326313
#        x: [-3.670e-02  1.826e-01 ...  7.364e-02 -6.508e-01]
#      nit: 8
#      jac: [-1.341e-07 -2.114e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09712739095627354
#        x: [-3.670e-02  1.826e-01 ... -3.670e-02  1.826e-01]
#      nit: 1
#      jac: [-4.260e-05  1.277e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0971637262087297
#        x: [-3.670e-02  1.826e-01 ... -3.670e-02  1.826e-01]
#      nit: 1
#      jac: [-6.942e-05  2.710e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0972543386064697
#        x: [-3.670e-02  1.826e-01 ... -3.670e-02  1.826e-01]
#      nit: 1
#      jac: [-9.178e-05  4.151e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09739913746841022
#        x: [-3.670e-02  1.826e-01 ... -3.670e-02  1.826e-01]
#      nit: 1
#      jac: [-1.096e-04  5.598e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09759797788592839
#        x: [-3.670e-02  1.826e-01 ... -3.670e-02  1.826e-01]
#      nit: 1
#      jac: [-1.228e-04  7.051e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09785066086788374
#        x: [-3.670e-02  1.826e-01 ... -3.670e-02  1.826e-01]
#      nit: 1
#      jac: [-1.315e-04  8.506e-04 ...  0.000e+00  0.000e+00]
#     nfev: 17
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.09753808391687158
#        x: [ 7.993e-02 -6.464e-01 ... -3.670e-02  1.826e-01]
#      nit: 8
#      jac: [-3.964e-06  6.489e-05 ...  0.000e+00  0.000e+00]
#     nfev: 136
#     njev: 8

# %%
plot_componentes(evolucao_1, 1)

# Controlabilidade da equação de lindblad, heisenberg
