# %%
# Bilbiotecas para auxílio na programação matemática
import math, sys 
import numpy as np
import sympy as sp
import cmath
import time

from scipy import sparse # Produção das diagonais das matrizes
from scipy.sparse import diags 
from scipy.linalg import expm

# Plotagem 2D e 3D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm


from os import path # Suficiente para manipulação de arquivos
    
# Para solução exata
from scipy.special import hermite
from math import factorial

# %matplotlib inline
count = 0

# Para otimização dos sistemas
from scipy import optimize
from random import randint, uniform, random

# %%
# Manipulação das matrizes, soma e subtração

def somar(A, B):
    C = []
    num_linhas_a = len(A)
    num_colunas_a = len(A[0])
    
    for i in range (num_linhas_a):
        linha = [0]*num_colunas_a
        C.append(linha)
        for j in range(num_colunas_a):
            C[i][j] = A[i][j] + B[i][j]

    return C

def sub(A, B):
    C = []
    num_linhas_a = len(A)
    num_colunas_a = len(A[0])
    
    for i in range (num_linhas_a):
        linha = [0]*num_colunas_a
        C.append(linha)
        for j in range(num_linhas_a):
            C[i][j] = A[i][j] - B[i][j]

    return C

# %%
## CONSTANTES PARA O CONTROLADOR

# Considerações: constante de Planck verdadeira: 1, massa: 1

TEMPO_ANALISE = 30 
QUANTIDADE_PONTOS_AMOSTRAGEM = 3000
PASSO = TEMPO_ANALISE/QUANTIDADE_PONTOS_AMOSTRAGEM

MIN_HORIZONTE = 3 # Horizonte mínimo da análise
MAX_HORIZONTE = 30 # Horizonte máximo da análise

# Com horizonte em 10, a avaliação dura em torno de 80 minutos 

DESEJADO = [[0.80],[0.60]] # [[c1];[c2]] = [[0.707],[-0.707]]
RHO_DESEJADO = np.matmul(DESEJADO, np.transpose(DESEJADO))

# Determinação dos valores de início e fim da análise
num = PASSO
contador = 0
while num < 1:
    num *= 10
    contador += 1

EXPOENTE = contador
INICIO_ANALISE = 0*10**(-EXPOENTE) # Tempo inicial da analise em um horizonte
FINAL_ANALISE = (1*10**(-EXPOENTE))+PASSO # Tempo final da analise em um horizonte

# %%
## CONSTANTES PARA O ALGORITMO GENÉTICO

ELITISMO = True
PORCENTAGEM_ELITISMO = 0.20

TAMANHO_POP = 50
TAXA_MUTACAO = 0.10
TAXA_CRUZAMENTO = 0.70
GERACOES = 100

# Valores mínimos e máximos para gerar uma população
MIN = -5
MAX = 5

# %%
def dpsi_dt(t, ro, H): # A derivada da ro em relação ao tempo não tem dependência temporal
    A = np.zeros((2,2), dtype=np.complex_)
    A = (np.dot(H,ro))-(np.dot(ro, H)) # [H,p]
    return -1j*A

# Runge-Kutta de quarta ordem

def runge_kutta(onda, fator_runge_kutta, hamiltoniano, tempo_inicial = 0):

    k1 = dpsi_dt(tempo_inicial, onda, hamiltoniano)
    k2 = dpsi_dt(tempo_inicial + 0.5 * fator_runge_kutta, somar(onda, np.dot((0.5*fator_runge_kutta), k1)), hamiltoniano)
    k3 = dpsi_dt(tempo_inicial + 0.5 * fator_runge_kutta, somar(onda, np.dot((0.5*fator_runge_kutta), k2)), hamiltoniano)
    k4 = dpsi_dt(tempo_inicial + fator_runge_kutta, somar(onda, np.dot(fator_runge_kutta, k3)), hamiltoniano)
    
    ## y(i+1) = y(i) + h/6*(k1+2*k2+2*k3+k4)
    
    A = somar(np.dot(2,k3), k4)
    B = somar(np.dot(2,k2), k1)
    C = somar(A, B)

    runge = somar(onda,np.dot((fator_runge_kutta / 6.0),(C)))
    
    return runge

# %%
def func_objetivo(vetor_controles, tempo_atual, rho_desejado, 
                  rho_atual, H, horizonte, fator_runge_kutta):
    
    fo = 0
    pos = 0
    
    tempo_inicial = INICIO_ANALISE
    tempo_final = FINAL_ANALISE
    
    controles = np.zeros((2,2), dtype=np.complex_)
    controles = [[0, complex(vetor_controles[0], vetor_controles[1])], 
                 [complex(vetor_controles[0], -vetor_controles[1]), 0]]
    
    matriz_inicial = rho_atual

    matriz_desejada = np.zeros((2,2),dtype=np.complex_)
    hamiltoniano = H

    H = [[np.exp(-1j*np.pi*tempo_atual/2),0],[0,np.exp(1j*np.pi*tempo_atual/2)]]
    U = H
    U = np.asmatrix(U)
    U_dagger = U.getH()
    teste = np.dot(np.dot(U,rho_desejado),U_dagger)
    matriz_desejada = np.squeeze(np.asarray(teste))

    matriz_teste = sub(matriz_inicial, matriz_desejada)

    teste = []
    for m in range(0, 2):
        teste.append(abs(matriz_teste[0][m])+abs(matriz_teste[0][m]))
    
    fo += max(teste)

    runge = runge_kutta(matriz_inicial, fator_runge_kutta, 
                        somar(hamiltoniano, controles), tempo_inicial = tempo_inicial)

    matriz_inicial = runge

    tempo_inicial = round(tempo_inicial+PASSO, EXPOENTE)
    tempo_final = round(tempo_final+PASSO, EXPOENTE)
    tempo = round(tempo_atual+PASSO, EXPOENTE)
    pos += 2

    while horizonte > 1:
        
        H = [[np.exp(-1j*np.pi*tempo/2),0],[0,np.exp(1j*np.pi*tempo/2)]]
        U = H
        U = np.asmatrix(U)
        U_dagger = U.getH()
        teste = np.dot(np.dot(U,rho_desejado),U_dagger)
        matriz_desejada = np.squeeze(np.asarray(teste))
        
        teste = []
        for m in range(0, 2):
            teste.append(abs(matriz_teste[0][m])+abs(matriz_teste[0][m]))

        matriz_teste = sub(matriz_inicial, matriz_desejada)
        
        fo += max(teste)
        
        controles = [[0, complex(vetor_controles[pos], vetor_controles[pos+1])], 
                     [complex(vetor_controles[pos], -vetor_controles[pos+1]), 0]]

        runge = runge_kutta(matriz_inicial, fator_runge_kutta, 
                        somar(hamiltoniano, controles), tempo_inicial = tempo_inicial)

        matriz_inicial = runge

        tempo_inicial = round(tempo_inicial+PASSO, EXPOENTE)
        tempo_final = round(tempo_final+PASSO, EXPOENTE)
        tempo = round(tempo_atual+PASSO, EXPOENTE)
        horizonte -= 1

    return fo

# %%
def main(horizonte, rho_inicial):
    
    u = [] # Controles 
    for i in range(0, 2*horizonte):
        u.append(uniform(-5,5))

    evolucao_1 = np.zeros((2,QUANTIDADE_PONTOS_AMOSTRAGEM), dtype=np.complex_)
    evolucao_2 = np.zeros((2,QUANTIDADE_PONTOS_AMOSTRAGEM), dtype=np.complex_)
        
    # O que será retornado por essa função
    
    vetor_controles = np.zeros((1, QUANTIDADE_PONTOS_AMOSTRAGEM), dtype=np.complex_) # Valores de controle
    constantes = np.zeros((2, QUANTIDADE_PONTOS_AMOSTRAGEM), dtype=np.complex_) # Para verificar se as integrais estão resultando em 1
    valores_onda = np.zeros((2, QUANTIDADE_PONTOS_AMOSTRAGEM), dtype=np.complex_)
    
    H = np.zeros((2,2), dtype=np.complex_)
    H = [[(3/2*np.pi), 0], [0, (1/2*np.pi)]]
    
    tempo = 0
    pos = 0
    while tempo < TEMPO_ANALISE:

        evolucao_1[0][pos] = rho_inicial[0][0]
        evolucao_1[1][pos] = rho_inicial[1][1]
    
        resultado = optimize.minimize(func_objetivo, u, args=(tempo, RHO_DESEJADO, rho_inicial, H, horizonte, PASSO), method='SLSQP')

        print('------------------')
        print(resultado)
        
        controle = np.zeros((2,2), dtype=np.complex_)
        controle = [[0, complex(resultado.x[0], resultado.x[1])],[complex(resultado.x[0], -resultado.x[1]), 0]]
        H = somar(H, controle)
    
        ## Adaptação da onda ao controle
        
        rho_avancado = runge_kutta(rho_inicial, PASSO, H, tempo_inicial = INICIO_ANALISE)
        rho_inicial = rho_avancado
        
        # Reset
        H = [[(3/2*np.pi), 0], [0, (1/2*np.pi)]]
    
        u = [] # Controles 
        for i in range(0, 2*horizonte):
            u.append(resultado.x[0])
            u.append(-resultado.x[1])
        
        pos += 1
        tempo = round(tempo+PASSO, EXPOENTE)

    return evolucao_1

# %%
# Plotagem 2D e 3D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm

def plot_componentes(valores_onda, componente):
    
    ts1 = np.linspace(0, TEMPO_ANALISE, QUANTIDADE_PONTOS_AMOSTRAGEM)
    
    real_primeiro = [elemento.real for elemento in valores_onda[componente-1]]
    
    # Plotagem

    plt.ylabel('Pesos') 
    plt.xlabel('Tempo') 
    plt.title(f"{componente}ª componente -> real")
    plt.plot(ts1, real_primeiro, color='r', marker='*', linewidth=1, markersize=1, label="primeiro")
    plt.legend(loc='upper right')
    

    plt.axis([0,TEMPO_ANALISE,0,1])
    plt.tight_layout()

# %%
PSI = np.ones((2,1), dtype=np.complex_)
PSI = [[0.80],[0.60]]
ro = np.matmul(PSI, np.transpose(PSI))
evolucao_1 = main(4, ro)
# Out:
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.02859180899768763
#        x: [ 3.965e+00  1.149e+00  4.312e-01 -9.360e-01 -3.040e+00
#             7.920e-01 -9.596e-01 -2.610e+00]
#      nit: 34
#      jac: [ 6.907e-06  3.115e-03 -5.579e-03  1.689e-03  0.000e+00
#             0.000e+00  0.000e+00  0.000e+00]
#     nfev: 348
#     njev: 34
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.06675372821885403
#        x: [-8.101e-01 -1.027e+00 ...  3.965e+00 -1.149e+00]
#      nit: 25
#      jac: [ 2.597e-04  9.386e-04 ...  0.000e+00  0.000e+00]
#     nfev: 447
#     njev: 25
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.03710412177263302
#        x: [-3.292e+00  1.097e-01 ... -8.101e-01  1.027e+00]
#      nit: 62
#      jac: [-7.063e-03 -2.179e-02 ...  0.000e+00  0.000e+00]
#     nfev: 1112
#     njev: 62
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.026273645383315926
#        x: [ 4.653e+00 -3.079e-01 ... -3.292e+00 -1.097e-01]
#      nit: 25
#      jac: [ 2.181e-04  1.041e-03 ...  0.000e+00  0.000e+00]
#     nfev: 449
#     njev: 25
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0076576479845509495
#        x: [-1.221e+00 -5.826e-01 ...  1.644e-03  3.343e-05]
#      nit: 17
#      jac: [ 2.340e-03 -2.032e-02 ...  0.000e+00  0.000e+00]
#     nfev: 318
#     njev: 17
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.037402210746360916
#        x: [-6.928e-01 -7.391e-01 ... -1.221e+00  5.826e-01]
#      nit: 16
#      jac: [ 7.817e-04 -2.384e-03 ...  0.000e+00  0.000e+00]
#     nfev: 307
#     njev: 16
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.02680761725131005
#        x: [ 1.911e+00  1.185e+00 ... -6.928e-01  7.391e-01]
#      nit: 30
#      jac: [-5.583e-04 -2.450e-04 ...  0.000e+00  0.000e+00]
#     nfev: 548
#     njev: 30
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.020157262650811768
#        x: [-2.938e+00 -9.670e-01 ...  1.911e+00 -1.185e+00]
#      nit: 32
#      jac: [-8.552e-04  1.982e-03 ...  0.000e+00  0.000e+00]
#     nfev: 585
#     njev: 32
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.037785315242915424
#        x: [ 3.001e+00  9.022e-01 ... -2.938e+00  9.670e-01]
#      nit: 47
#      jac: [-6.769e-04 -1.764e-02 ...  0.000e+00  0.000e+00]
#     nfev: 848
#     njev: 47
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0001766036251260118
#        x: [-5.548e-03  5.046e-04 ...  3.001e+00 -9.022e-01]
#      nit: 62
#      jac: [-9.040e-03  1.651e-02 ...  0.000e+00  0.000e+00]
#     nfev: 1111
#     njev: 62
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0004794094697495588
#        x: [-2.908e-02  3.579e-03 ... -5.548e-03 -5.046e-04]
#      nit: 21
#      jac: [-1.680e-03 -1.801e-02 ...  0.000e+00  0.000e+00]
#     nfev: 383
#     njev: 21
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0010715430199990255
#        x: [-4.360e-02  6.785e-03 ... -2.908e-02 -3.579e-03]
#      nit: 29
#      jac: [-1.042e-02 -3.178e-03 ...  0.000e+00  0.000e+00]
#     nfev: 523
#     njev: 29
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0009537960208545471
#        x: [ 8.107e-02 -1.525e-02 ... -4.360e-02 -6.785e-03]
#      nit: 34
#      jac: [ 4.798e-03 -3.798e-02 ...  0.000e+00  0.000e+00]
#     nfev: 606
#     njev: 34
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.022846972798389986
#        x: [-2.392e+00 -6.775e-01 ...  8.107e-02  1.525e-02]
#      nit: 15
#      jac: [ 6.303e-05 -2.207e-03 ...  0.000e+00  0.000e+00]
#     nfev: 283
#     njev: 15
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.028288399271554035
#        x: [ 2.410e+00  6.019e-01 ... -2.392e+00  6.775e-01]
#      nit: 56
#      jac: [ 4.510e-03  1.929e-02 ...  0.000e+00  0.000e+00]
#     nfev: 997
#     njev: 56
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.023524547330326256
#        x: [-4.179e+00 -7.609e-02 ...  2.410e+00 -6.019e-01]
#      nit: 20
#      jac: [-6.466e-03  1.823e-02 ...  0.000e+00  0.000e+00]
#     nfev: 373
#     njev: 20
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.06664133302575502
#        x: [ 6.718e-01  4.881e-01 ... -4.179e+00  7.609e-02]
#      nit: 24
#      jac: [ 6.328e-06  7.902e-04 ...  0.000e+00  0.000e+00]
#     nfev: 433
#     njev: 24
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.000574606217155394
#        x: [ 2.490e-03 -1.728e-04 ...  4.053e-03  9.576e-04]
#      nit: 47
#      jac: [ 3.946e-03  1.896e-02 ...  0.000e+00  0.000e+00]
#     nfev: 849
#     njev: 47
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010788235862473426
#        x: [-1.744e+00  7.787e-01 ...  2.490e-03  1.728e-04]
#      nit: 20
#      jac: [ 9.506e-04  2.176e-03 ...  0.000e+00  0.000e+00]
#     nfev: 361
#     njev: 20
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.021492258775360863
#        x: [ 1.715e+00 -8.312e-01 ... -1.744e+00 -7.787e-01]
#      nit: 57
#      jac: [ 5.032e-03  1.874e-02 ...  0.000e+00  0.000e+00]
#     nfev: 1004
#     njev: 57
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01900364852976967
#        x: [-3.071e+00  1.045e+00 ...  1.715e+00  8.312e-01]
#      nit: 29
#      jac: [ 4.635e-04  9.538e-04 ...  0.000e+00  0.000e+00]
#     nfev: 531
#     njev: 29
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.03751990068223135
#        x: [ 3.019e+00 -1.133e+00 ... -3.071e+00 -1.045e+00]
#      nit: 40
#      jac: [-9.539e-03  5.790e-03 ...  0.000e+00  0.000e+00]
#     nfev: 708
#     njev: 40
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.025675615686740042
#        x: [-3.189e+00  1.677e+00 ...  3.019e+00  1.133e+00]
#      nit: 19
#      jac: [ 4.955e-04  1.036e-03 ...  0.000e+00  0.000e+00]
#     nfev: 348
#     njev: 19
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.043846999786903665
#        x: [ 3.204e+00 -1.841e+00 ... -3.189e+00 -1.677e+00]
#      nit: 51
#      jac: [ 7.652e-03 -8.303e-03 ...  0.000e+00  0.000e+00]
#     nfev: 918
#     njev: 51
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.02121865187858143
#        x: [-3.031e+00  1.987e+00 ...  3.204e+00  1.841e+00]
#      nit: 35
#      jac: [ 8.641e-04  1.408e-03 ...  0.000e+00  0.000e+00]
#     nfev: 632
#     njev: 35
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.06622798896293344
#        x: [ 2.496e-01  1.746e+00 ... -3.031e+00 -1.987e+00]
#      nit: 17
#      jac: [ 2.002e-03  2.461e-03 ...  0.000e+00  0.000e+00]
#     nfev: 303
#     njev: 17
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.07949238280385905
#        x: [ 9.023e-01 -1.181e+00 ...  2.496e-01 -1.746e+00]
#      nit: 15
#      jac: [ 2.100e-03  2.349e-03 ...  0.000e+00  0.000e+00]
#     nfev: 281
#     njev: 15
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.03900644013329923
#        x: [ 1.635e+00 -2.726e+00 ...  9.023e-01  1.181e+00]
#      nit: 23
#      jac: [ 1.911e-02  1.111e-02 ...  0.000e+00  0.000e+00]
#     nfev: 412
#     njev: 23
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.001758753515090174
#        x: [ 6.462e-02 -1.363e-01 ...  1.635e+00  2.726e+00]
#      nit: 53
#      jac: [ 3.643e-03  3.529e-03 ...  0.000e+00  0.000e+00]
#     nfev: 951
#     njev: 53
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0017246935572675004
#        x: [-1.200e-01  2.741e-01 ...  6.462e-02  1.363e-01]
#      nit: 31
#      jac: [-1.640e-02 -7.776e-03 ...  0.000e+00  0.000e+00]
#     nfev: 559
#     njev: 31
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.008171243746875008
#        x: [-3.886e-01  4.098e-01 ... -1.200e-01 -2.741e-01]
#      nit: 15
#      jac: [-1.789e-02 -7.967e-03 ...  0.000e+00  0.000e+00]
#     nfev: 273
#     njev: 15
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.03901099657659984
#        x: [ 1.242e-01  2.576e-01 ... -3.886e-01 -4.098e-01]
#      nit: 12
#      jac: [ 1.306e-03  6.960e-04 ...  0.000e+00  0.000e+00]
#     nfev: 223
#     njev: 12
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.04154182586759132
#        x: [-3.644e-01 -4.373e-01 ...  1.242e-01 -2.576e-01]
#      nit: 11
#      jac: [-1.456e-03 -1.322e-03 ...  0.000e+00  0.000e+00]
#     nfev: 204
#     njev: 11
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0174807916446104
#        x: [ 4.869e-02  6.596e-01 ... -3.644e-01  4.373e-01]
#      nit: 14
#      jac: [-5.738e-03  9.368e-03 ...  0.000e+00  0.000e+00]
#     nfev: 259
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.015276165987397708
#        x: [ 5.865e-01 -1.239e+00 ...  4.869e-02 -6.596e-01]
#      nit: 48
#      jac: [-1.817e-03 -1.180e-03 ...  0.000e+00  0.000e+00]
#     nfev: 847
#     njev: 48
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.02540577710385542
#        x: [-5.943e-01  5.553e-01 ...  5.865e-01  1.239e+00]
#      nit: 12
#      jac: [-7.252e-04 -6.884e-04 ...  0.000e+00  0.000e+00]
#     nfev: 222
#     njev: 12
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.009202903986060605
#        x: [ 5.763e-01 -5.738e-01 ... -5.943e-01 -5.553e-01]
#      nit: 50
#      jac: [-2.214e-02 -5.479e-03 ...  0.000e+00  0.000e+00]
#     nfev: 894
#     njev: 50
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0035224903319938912
#        x: [-2.691e-01  5.381e-01 ...  5.763e-01  5.738e-01]
#      nit: 22
#      jac: [-8.208e-03  8.090e-03 ...  0.000e+00  0.000e+00]
#     nfev: 393
#     njev: 22
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01318251600691214
#        x: [-3.405e-01  4.078e-01 ... -2.691e-01 -5.381e-01]
#      nit: 20
#      jac: [-6.691e-04 -1.098e-04 ...  0.000e+00  0.000e+00]
#     nfev: 358
#     njev: 20
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.04266428907724061
#        x: [ 4.438e-01  2.075e-01 ... -3.405e-01 -4.078e-01]
#      nit: 14
#      jac: [ 1.582e-03  4.066e-04 ...  0.000e+00  0.000e+00]
#     nfev: 260
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.022196556265169413
#        x: [-5.134e-01  1.938e-01 ...  4.438e-01 -2.075e-01]
#      nit: 20
#      jac: [ 1.541e-02  1.239e-02 ...  0.000e+00  0.000e+00]
#     nfev: 363
#     njev: 20
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.04527121175691657
#        x: [ 4.741e-01  4.798e-01 ... -5.134e-01 -1.938e-01]
#      nit: 16
#      jac: [ 1.914e-03  4.307e-04 ...  0.000e+00  0.000e+00]
#     nfev: 291
#     njev: 16
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.05252187773592755
#        x: [-8.824e-01 -5.553e-01 ...  4.741e-01 -4.798e-01]
#      nit: 12
#      jac: [-1.842e-03 -8.354e-04 ...  0.000e+00  0.000e+00]
#     nfev: 225
#     njev: 12
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.018390700283225887
#        x: [ 8.467e-01 -1.277e+00 ... -8.824e-01  5.553e-01]
#      nit: 35
#      jac: [-1.856e-02  1.084e-04 ...  0.000e+00  0.000e+00]
#     nfev: 621
#     njev: 35
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.002211584066073846
#        x: [ 2.050e-02  2.594e-01 ...  8.467e-01  1.277e+00]
#      nit: 32
#      jac: [ 2.170e-03  4.618e-04 ...  0.000e+00  0.000e+00]
#     nfev: 583
#     njev: 32
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0013776751903150234
#        x: [-5.823e-02 -9.937e-02 ...  5.752e-02 -1.066e-01]
#      nit: 41
#      jac: [ 3.736e-02 -8.351e-03 ...  0.000e+00  0.000e+00]
#     nfev: 725
#     njev: 41
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0002458749646240045
#        x: [-2.639e-03 -3.008e-03 ... -5.823e-02  9.937e-02]
#      nit: 26
#      jac: [ 4.362e-05  6.112e-04 ...  0.000e+00  0.000e+00]
#     nfev: 463
#     njev: 26
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 1.4963241511072052e-05
#        x: [-2.132e-04 -1.230e-03 ... -2.639e-03  3.008e-03]
#      nit: 49
#      jac: [ 6.163e-05  6.108e-04 ...  0.000e+00  0.000e+00]
#     nfev: 870
#     njev: 49
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 1.004657925135151e-05
#        x: [ 2.161e-04  6.304e-04 ... -2.132e-04  1.230e-03]
#      nit: 31
#      jac: [ 1.943e-02 -1.382e-04 ...  0.000e+00  0.000e+00]
#     nfev: 559
#     njev: 31
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0004276308098829323
#        x: [-4.546e-03 -6.605e-02 ...  2.161e-04 -6.304e-04]
#      nit: 45
#      jac: [ 3.602e-02 -1.297e-02 ...  0.000e+00  0.000e+00]
#     nfev: 816
#     njev: 45
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.009706415458530352
#        x: [ 1.668e-01  9.720e-01 ... -4.546e-03  6.605e-02]
#      nit: 13
#      jac: [-1.704e-02  1.244e-02 ...  0.000e+00  0.000e+00]
#     nfev: 252
#     njev: 13
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.011352740885063557
#        x: [-1.016e-01 -8.024e-01 ...  1.668e-01 -9.720e-01]
#      nit: 24
#      jac: [ 2.148e-02 -3.123e-03 ...  0.000e+00  0.000e+00]
#     nfev: 436
#     njev: 24
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.026597740372949267
#        x: [ 6.243e-01  6.778e-01 ... -1.016e-01  8.024e-01]
#      nit: 9
#      jac: [ 1.579e-03 -1.026e-03 ...  0.000e+00  0.000e+00]
#     nfev: 170
#     njev: 9
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0117051102975109
#        x: [-7.377e-01 -7.508e-01 ...  6.243e-01 -6.778e-01]
#      nit: 25
#      jac: [-1.905e-04 -5.732e-04 ...  0.000e+00  0.000e+00]
#     nfev: 446
#     njev: 25
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 4.645252664967375e-05
#        x: [-1.235e-03 -1.187e-03 ... -7.377e-01  7.508e-01]
#      nit: 38
#      jac: [-2.036e-02  4.551e-03 ...  0.000e+00  0.000e+00]
#     nfev: 671
#     njev: 38
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.003801006518724368
#        x: [ 1.569e-01  6.152e-01 ... -1.235e-03  1.187e-03]
#      nit: 26
#      jac: [-1.671e-02  1.639e-02 ...  0.000e+00  0.000e+00]
#     nfev: 463
#     njev: 26
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.007158670128924594
#        x: [-1.762e-01 -6.100e-01 ...  1.569e-01 -6.152e-01]
#      nit: 45
# ...
#      jac: [ 2.249e-02 -4.433e-04 ...  0.000e+00  0.000e+00]
#     nfev: 280
#     njev: 15
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.022372690607286846
#        x: [-2.388e-01 -1.932e+00 ...  1.751e-01 -1.945e+00]
#      nit: 41
#      jac: [ 1.483e-02  7.911e-03 ...  0.000e+00  0.000e+00]
#     nfev: 726
#     njev: 41
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 3.110350322783147e-05
#        x: [-2.518e-04 -2.475e-03 ... -2.388e-01  1.932e+00]
#      nit: 40
#      jac: [ 2.210e-02 -2.472e-03 ...  0.000e+00  0.000e+00]
#     nfev: 715
#     njev: 40
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 7.806972878195967e-06
#        x: [ 2.602e-05  7.384e-04 ... -2.518e-04  2.475e-03]
#      nit: 25
#      jac: [-7.230e-03  4.555e-03 ...  0.000e+00  0.000e+00]
#     nfev: 444
#     njev: 25
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.030170617910422144
#        x: [-8.334e-05 -7.157e-04 ...  2.602e-05 -7.384e-04]
#      nit: 1
#      jac: [ 1.967e-02 -4.069e-03 ...  0.000e+00  0.000e+00]
#     nfev: 23
#     njev: 1
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 2.6551547599425247e-05
#        x: [ 4.387e-04  2.102e-03 ... -8.334e-05  7.157e-04]
#      nit: 42
#      jac: [ 1.490e-04 -5.952e-04 ...  0.000e+00  0.000e+00]
#     nfev: 748
#     njev: 42
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 5.473464014816611e-05
#        x: [-3.456e-05 -2.663e-03 ...  4.387e-04 -2.102e-03]
#      nit: 56
#      jac: [ 3.916e-03 -1.096e-02 ...  0.000e+00  0.000e+00]
#     nfev: 998
#     njev: 56
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.005007224039148772
#        x: [ 1.453e-01  2.576e-01 ... -3.456e-05  2.663e-03]
#      nit: 11
#      jac: [ 3.833e-02 -1.170e-05 ...  0.000e+00  0.000e+00]
#     nfev: 213
#     njev: 11
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.005608404631658407
#        x: [-1.548e-01 -2.481e-01 ...  1.453e-01 -2.576e-01]
#      nit: 34
#      jac: [-3.827e-02  1.202e-03 ...  0.000e+00  0.000e+00]
#     nfev: 605
#     njev: 34
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.02810178324208753
#        x: [ 1.211e-01  3.037e-01 ... -1.548e-01  2.481e-01]
#      nit: 10
#      jac: [ 1.738e-03 -3.746e-04 ...  0.000e+00  0.000e+00]
#     nfev: 185
#     njev: 10
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.004409800086604854
#        x: [-1.269e-01 -3.183e-01 ...  1.211e-01 -3.037e-01]
#      nit: 35
#      jac: [ 4.949e-05 -6.015e-04 ...  0.000e+00  0.000e+00]
#     nfev: 635
#     njev: 35
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.00017578741344936736
#        x: [-2.532e-03  1.456e-02 ... -1.269e-01  3.183e-01]
#      nit: 51
#      jac: [-2.407e-03  3.219e-05 ...  0.000e+00  0.000e+00]
#     nfev: 900
#     njev: 51
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.015138058368309263
#        x: [ 4.527e-01  2.654e+00 ... -2.532e-03 -1.456e-02]
#      nit: 15
#      jac: [-5.494e-04  3.374e-04 ...  0.000e+00  0.000e+00]
#     nfev: 277
#     njev: 15
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.041740648820280016
#        x: [-6.558e-01 -1.375e+00 ...  4.527e-01 -2.654e+00]
#      nit: 20
#      jac: [ 1.042e-04  5.505e-04 ...  0.000e+00  0.000e+00]
#     nfev: 368
#     njev: 20
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.015131296110849846
#        x: [ 8.863e-02 -1.234e+00 ... -6.558e-01  1.375e+00]
#      nit: 31
#      jac: [ 1.819e-02 -9.466e-03 ...  0.000e+00  0.000e+00]
#     nfev: 553
#     njev: 31
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.00019440754691069095
#        x: [-2.187e-03  1.945e-03 ...  8.863e-02  1.234e+00]
#      nit: 41
#      jac: [-3.708e-02  9.517e-03 ...  0.000e+00  0.000e+00]
#     nfev: 752
#     njev: 41
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.001897765344260562
#        x: [ 3.943e-02  5.587e-02 ... -2.187e-03 -1.945e-03]
#      nit: 35
#      jac: [ 2.151e-02 -3.790e-04 ...  0.000e+00  0.000e+00]
#     nfev: 635
#     njev: 35
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0007720884713790743
#        x: [-3.894e-02 -5.405e-02 ...  3.943e-02 -5.587e-02]
#      nit: 35
#      jac: [-1.565e-03  5.064e-05 ...  0.000e+00  0.000e+00]
#     nfev: 625
#     njev: 35
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 1.3546610806591184e-05
#        x: [-3.924e-04 -4.303e-04 ... -3.894e-02  5.405e-02]
#      nit: 33
#      jac: [ 1.638e-02 -1.188e-02 ...  0.000e+00  0.000e+00]
#     nfev: 581
#     njev: 33
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0021644294375935537
#        x: [ 3.256e-02  3.437e-01 ... -3.924e-04  4.303e-04]
#      nit: 24
#      jac: [-1.913e-02  1.362e-02 ...  0.000e+00  0.000e+00]
#     nfev: 445
#     njev: 24
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.00400821515534434
#        x: [-4.268e-02 -3.316e-01 ...  3.256e-02 -3.437e-01]
#      nit: 32
#      jac: [ 1.451e-04  5.953e-04 ...  0.000e+00  0.000e+00]
#     nfev: 559
#     njev: 32
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0059570880536519025
#        x: [ 5.534e-01  8.674e-01 ... -4.268e-02  3.316e-01]
#      nit: 21
#      jac: [ 3.059e-03 -1.376e-03 ...  0.000e+00  0.000e+00]
#     nfev: 383
#     njev: 21
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.011589534906094507
#        x: [-5.810e-01 -8.591e-01 ...  5.534e-01 -8.674e-01]
#      nit: 42
#      jac: [-2.264e-03  1.115e-02 ...  0.000e+00  0.000e+00]
#     nfev: 747
#     njev: 42
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 1.4491745417354484e-05
#        x: [-3.312e-04 -1.022e-03 ... -5.810e-01  8.591e-01]
#      nit: 45
#      jac: [-8.301e-03  3.046e-03 ...  0.000e+00  0.000e+00]
#     nfev: 796
#     njev: 45
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.002590244890736532
#        x: [ 1.480e-01  4.353e-01 ... -3.312e-04  1.022e-03]
#      nit: 14
#      jac: [ 1.929e-03  1.165e-02 ...  0.000e+00  0.000e+00]
#     nfev: 255
#     njev: 14
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.006887864377767381
#        x: [ 3.807e-02 -2.645e-01 ...  1.480e-01 -4.353e-01]
#      nit: 22
#      jac: [ 6.436e-03  8.784e-03 ...  0.000e+00  0.000e+00]
#     nfev: 404
#     njev: 22
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0029234078233555433
#        x: [-2.057e-01 -1.609e-01 ...  3.807e-02  2.645e-01]
#      nit: 32
#      jac: [ 1.401e-02 -4.571e-03 ...  0.000e+00  0.000e+00]
#     nfev: 562
#     njev: 32
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.006026694212609139
#        x: [ 6.891e-01  6.794e-01 ... -2.057e-01  1.609e-01]
#      nit: 19
#      jac: [ 8.477e-04 -4.321e-04 ...  0.000e+00  0.000e+00]
#     nfev: 343
#     njev: 19
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010869199662101156
#        x: [-7.112e-01 -6.585e-01 ...  6.891e-01 -6.794e-01]
#      nit: 30
#      jac: [-5.040e-03 -9.745e-03 ...  0.000e+00  0.000e+00]
#     nfev: 541
#     njev: 30
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 2.16655463860446e-05
#        x: [ 1.124e-03  1.435e-03 ... -7.112e-01  6.585e-01]
#      nit: 36
#      jac: [-2.991e-04 -5.361e-04 ...  0.000e+00  0.000e+00]
#     nfev: 638
#     njev: 36
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0038769094783456096
#        x: [ 5.520e-01  3.311e-01 ...  1.124e-03 -1.435e-03]
#      nit: 28
#      jac: [-2.600e-04 -4.794e-04 ...  0.000e+00  0.000e+00]
#     nfev: 505
#     njev: 28
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.03561900340604297
#        x: [-1.799e-01  4.352e-01 ...  5.520e-01 -3.311e-01]
#      nit: 13
#      jac: [-1.293e-03  9.032e-04 ...  0.000e+00  0.000e+00]
#     nfev: 239
#     njev: 13
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.00939852816643812
#        x: [-3.981e-01 -7.294e-01 ... -1.799e-01 -4.352e-01]
#      nit: 32
#      jac: [ 1.380e-02 -7.742e-03 ...  0.000e+00  0.000e+00]
#     nfev: 568
#     njev: 32
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 7.223038950352344e-06
#        x: [-3.135e-04 -4.046e-04 ... -3.981e-01  7.294e-01]
#      nit: 30
#      jac: [-8.559e-03 -6.631e-03 ...  0.000e+00  0.000e+00]
#     nfev: 533
#     njev: 30
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0022720873893541135
#        x: [ 1.461e-01  2.299e-01 ... -3.135e-04  4.046e-04]
#      nit: 21
#      jac: [-1.497e-02  8.957e-03 ...  0.000e+00  0.000e+00]
#     nfev: 385
#     njev: 21
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.032621604478554986
#        x: [ 2.749e-02  4.047e-02 ...  1.461e-01 -2.299e-01]
#      nit: 12
#      jac: [-1.021e-03  8.878e-04 ...  0.000e+00  0.000e+00]
#     nfev: 226
#     njev: 12
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.003628727510754753
#        x: [-1.873e-01 -2.588e-01 ...  2.749e-02 -4.047e-02]
#      nit: 33
#      jac: [-7.233e-03  1.797e-02 ...  0.000e+00  0.000e+00]
#     nfev: 591
#     njev: 33
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 2.8766416198435743e-05
#        x: [-6.485e-04 -4.023e-04 ... -1.873e-01  2.588e-01]
#      nit: 45
#      jac: [-4.230e-04 -4.449e-04 ...  0.000e+00  0.000e+00]
#     nfev: 800
#     njev: 45
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0015982600842130434
#        x: [ 1.724e-01  2.089e-01 ... -6.485e-04  4.023e-04]
#      nit: 30
#      jac: [-2.154e-02  3.164e-02 ...  0.000e+00  0.000e+00]
#     nfev: 543
#     njev: 30
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.006751232064241214
#        x: [ 3.481e-01 -6.561e-02 ...  1.724e-01 -2.089e-01]
#      nit: 29
#      jac: [ 1.586e-02 -1.449e-02 ...  0.000e+00  0.000e+00]
#     nfev: 530
#     njev: 29
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0146790381132666
#        x: [ 8.059e-01  6.329e-01 ...  3.481e-01  6.561e-02]
#      nit: 20
#      jac: [ 8.033e-05  5.262e-04 ...  0.000e+00  0.000e+00]
#     nfev: 362
#     njev: 20
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01722725791348777
#        x: [-1.356e+00 -7.089e-01 ...  8.059e-01 -6.329e-01]
#      nit: 30
#      jac: [ 4.342e-03 -1.970e-02 ...  0.000e+00  0.000e+00]
#     nfev: 530
#     njev: 30
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.02899937261462244
#        x: [ 1.174e+00  1.063e+00 ... -1.356e+00  7.089e-01]
#      nit: 19
#      jac: [-1.377e-03  2.832e-03 ...  0.000e+00  0.000e+00]
#     nfev: 346
#     njev: 19
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01800121203529794
#        x: [-1.205e+00 -1.026e+00 ...  1.174e+00 -1.063e+00]
#      nit: 40
#      jac: [ 1.244e-02 -1.329e-02 ...  0.000e+00  0.000e+00]
#     nfev: 713
#     njev: 40
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.019517288674591515
#        x: [ 3.146e+00  1.255e+00 ... -1.205e+00  1.026e+00]
#      nit: 24
#      jac: [ 1.237e-03 -2.199e-03 ...  0.000e+00  0.000e+00]
#     nfev: 432
#     njev: 24
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.03783557202686684
#        x: [-3.181e+00 -1.154e+00 ...  3.146e+00 -1.255e+00]
#      nit: 51
#      jac: [-3.568e-03  7.611e-03 ...  0.000e+00  0.000e+00]
#     nfev: 906
#     njev: 51
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0737806200085053
#        x: [-2.224e+00 -1.554e+00 ... -3.181e+00  1.154e+00]
#      nit: 12
#      jac: [-1.024e-02 -3.035e-03 ...  0.000e+00  0.000e+00]
#     nfev: 220
#     njev: 12
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.045141298134037014
#        x: [ 3.830e+00  2.369e+00 ... -2.224e+00  1.554e+00]
#      nit: 33
#      jac: [ 5.801e-04 -1.327e-03 ...  0.000e+00  0.000e+00]
#     nfev: 602
#     njev: 33
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.06182700209040264
#        x: [ 2.726e+00  1.142e+00 ...  3.830e+00 -2.369e+00]
#      nit: 11
#      jac: [ 1.038e-02  4.787e-03 ...  0.000e+00  0.000e+00]
#     nfev: 211
#     njev: 11
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.07996647946342353
#        x: [-2.997e-01 -6.552e-01 ...  2.726e+00 -1.142e+00]
#      nit: 16
#      jac: [ 1.065e-02 -1.699e-02 ...  0.000e+00  0.000e+00]
#     nfev: 303
#     njev: 16
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.048650078422021896
#        x: [-4.179e+00 -1.075e+00 ... -2.997e-01  6.552e-01]
#      nit: 61
#      jac: [ 4.584e-03 -1.320e-02 ...  0.000e+00  0.000e+00]
#     nfev: 1068
#     njev: 61
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.03239994111953323
#        x: [ 1.575e+00  6.368e-01 ... -4.179e+00  1.075e+00]
#      nit: 22
#      jac: [-4.109e-04  2.980e-03 ...  0.000e+00  0.000e+00]
#     nfev: 410
#     njev: 22
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01928661531867189
#        x: [-1.592e+00 -5.862e-01 ...  1.575e+00 -6.368e-01]
#      nit: 35
#      jac: [-8.068e-03  1.670e-02 ...  0.000e+00  0.000e+00]
#     nfev: 617
#     njev: 35
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.032227400226142774
#        x: [ 1.330e+00  7.441e-01 ... -1.592e+00  5.862e-01]
#      nit: 20
#      jac: [-7.844e-03  1.971e-02 ...  0.000e+00  0.000e+00]
#     nfev: 368
#     njev: 20
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.022548533010352152
#        x: [-1.354e+00 -7.024e-01 ...  1.330e+00 -7.441e-01]
#      nit: 47
#      jac: [-8.718e-05  1.128e-02 ...  0.000e+00  0.000e+00]
#     nfev: 834
#     njev: 47
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.04732107233959375
#        x: [-9.902e-01 -3.467e-01 ... -1.354e+00  7.024e-01]
#      nit: 10
#      jac: [-1.081e-02 -1.092e-03 ...  0.000e+00  0.000e+00]
#     nfev: 190
#     njev: 10
# ------------------
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.03348641706443452
#        x: [ 4.013e+00 -1.091e-02 ... -9.902e-01  3.467e-01]
#      nit: 16
#      jac: [ 2.954e-04 -2.966e-03 ...  0.000e+00  0.000e+00]
#     nfev: 298
#     njev: 16

# %%
plot_componentes(evolucao_1, 1)

# Controlabilidade da equação de lindblad, heisenberg
